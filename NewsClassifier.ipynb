# %% [markdown]
# <a href="https://colab.research.google.com/github/TanviDeore/Amazing-Python-Scripts/blob/master/NewsClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.6.17.tar.gz (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105786 sha256=a2f7cd8bab81525fc423af2fe4e05e9747245b8c874303a24025f6110b4a5442
#   Stored in directory: /root/.cache/pip/wheels/9f/af/22/bf406f913dc7506a485e60dce8143741abd0a92a19337d83a3
# Successfully built kaggle
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.6.17
#     Uninstalling kaggle-1.6.17:
#       Successfully uninstalled kaggle-1.6.17
# Successfully installed kaggle-1.6.17

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.13.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import matplotlib.pyplot as plt

# %%
# !mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json

api_token = {"username":"tanvideore","key":"f925c13a9a8e6a4489a9243c898ad727"}

import json

with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(api_token, file)

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download rmisra/news-category-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rmisra/news-category-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# news-category-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
from zipfile import ZipFile

# %%
file_name = "news-category-dataset.zip"

# %%
with ZipFile(file_name, 'r') as zip:
    zip.extractall()
    print('Done!')
# Out:
# Done!

# %%
import pandas as pd
from pathlib import Path
import json
import shutil

# %%
df = pd.read_json('/content/News_Category_Dataset_v3.json',lines=True)
df
# Out:
#                                                      link  \
# 0       https://www.huffpost.com/entry/covid-boosters-...
# 1       https://www.huffpost.com/entry/american-airlin...
# 2       https://www.huffpost.com/entry/funniest-tweets...
# 3       https://www.huffpost.com/entry/funniest-parent...
# 4       https://www.huffpost.com/entry/amy-cooper-lose...
# ...                                                   ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3       The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
# ...                                                   ...        ...
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...       TECH
# 209523  Maria Sharapova Stunned By Victoria Azarenka I...     SPORTS
# 209524  Giants Over Patriots, Jets Over Colts Among  M...     SPORTS
# 209525  Aldon Smith Arrested: 49ers Linebacker Busted ...     SPORTS
# 209526  Dwight Howard Rips Teammates After Magic Loss ...     SPORTS
#
#                                         short_description  \
# 0       Health experts said it is too early to predict...
# 1       He was subdued by passengers and crew when he ...
# 2       "Until you have a dog you don't understand wha...
# 3       "Accidentally put grown-up toothpaste on my to...
# 4       Amy Cooper accused investment firm Franklin Te...
# ...                                                   ...
# 209522  Verizon Wireless and AT&T are already promotin...
# 209523  Afterward, Azarenka, more effusive with the pr...
# 209524  Leading up to Super Bowl XLVI, the most talked...
# 209525  CORRECTION: An earlier version of this story i...
# 209526  The five-time all-star center tore into his te...
#
#                      authors       date
# 0       Carla K. Johnson, AP 2022-09-23
# 1             Mary Papenfuss 2022-09-23
# 2              Elyse Wanshel 2022-09-23
# 3           Caroline Bologna 2022-09-23
# 4             Nina Golgowski 2022-09-22
# ...                      ...        ...
# 209522      Reuters, Reuters 2012-01-28
# 209523                       2012-01-28
# 209524                       2012-01-28
# 209525                       2012-01-28
# 209526                       2012-01-28
#
# [209527 rows x 6 columns]

# %%
# reading the json file
with open('/content/News_Category_Dataset_v3.json') as f:
    data = [json.loads(line) for line in f]

# %%
# creating the dataframe
dataframe = pd.json_normalize(data)

# converted a file to csv
df.to_csv('news_classification.csv', encoding='utf-8', index=False)

# %%
pd.read_csv('/content/news_classification.csv')
# Out:
#                                                      link  \
# 0       https://www.huffpost.com/entry/covid-boosters-...
# 1       https://www.huffpost.com/entry/american-airlin...
# 2       https://www.huffpost.com/entry/funniest-tweets...
# 3       https://www.huffpost.com/entry/funniest-parent...
# 4       https://www.huffpost.com/entry/amy-cooper-lose...
# ...                                                   ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3       The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
# ...                                                   ...        ...
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...       TECH
# 209523  Maria Sharapova Stunned By Victoria Azarenka I...     SPORTS
# 209524  Giants Over Patriots, Jets Over Colts Among  M...     SPORTS
# 209525  Aldon Smith Arrested: 49ers Linebacker Busted ...     SPORTS
# 209526  Dwight Howard Rips Teammates After Magic Loss ...     SPORTS
#
#                                         short_description  \
# 0       Health experts said it is too early to predict...
# 1       He was subdued by passengers and crew when he ...
# 2       "Until you have a dog you don't understand wha...
# 3       "Accidentally put grown-up toothpaste on my to...
# 4       Amy Cooper accused investment firm Franklin Te...
# ...                                                   ...
# 209522  Verizon Wireless and AT&T are already promotin...
# 209523  Afterward, Azarenka, more effusive with the pr...
# 209524  Leading up to Super Bowl XLVI, the most talked...
# 209525  CORRECTION: An earlier version of this story i...
# 209526  The five-time all-star center tore into his te...
#
#                      authors        date
# 0       Carla K. Johnson, AP  2022-09-23
# 1             Mary Papenfuss  2022-09-23
# 2              Elyse Wanshel  2022-09-23
# 3           Caroline Bologna  2022-09-23
# 4             Nina Golgowski  2022-09-22
# ...                      ...         ...
# 209522      Reuters, Reuters  2012-01-28
# 209523                   NaN  2012-01-28
# 209524                   NaN  2012-01-28
# 209525                   NaN  2012-01-28
# 209526                   NaN  2012-01-28
#
# [209527 rows x 6 columns]

# %%
df.to_csv('news_classification_model.csv', encoding='utf-8', index=False)

# %%
df.shape
# Out:
# (44986, 2)

# %%
df.isna().sum()
# Out:
# link                 0
# headline             0
# category             0
# short_description    0
# authors              0
# date                 0
# dtype: int64

# %%
df.head(10)
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
# 5  https://www.huffpost.com/entry/belk-worker-fou...
# 6  https://www.huffpost.com/entry/reporter-gets-a...
# 7  https://www.huffpost.com/entry/puerto-rico-wat...
# 8  https://www.huffpost.com/entry/mija-documentar...
# 9  https://www.huffpost.com/entry/biden-un-russia...
#
#                                             headline        category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...       U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...       U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...          COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...       PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...       U.S. NEWS
# 5  Cleaner Was Dead In Belk Bathroom For 4 Days B...       U.S. NEWS
# 6  Reporter Gets Adorable Surprise From Her Boyfr...       U.S. NEWS
# 7  Puerto Ricans Desperate For Water After Hurric...      WORLD NEWS
# 8  How A New Documentary Captures The Complexity ...  CULTURE & ARTS
# 9  Biden At UN To Call Russian War An Affront To ...      WORLD NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
# 5  The 63-year-old woman was seen working at the ...
# 6  "Who's that behind you?" an anchor for New Yor...         Elyse Wanshel
# 7  More than half a million people remained witho...       DÁNICA COTO, AP
# 8  In "Mija," director Isabel Castro combined mus...           Marina Fang
# 9  White House officials say the crux of the pres...     Aamer Madhani, AP
#
#         date
# 0 2022-09-23
# 1 2022-09-23
# 2 2022-09-23
# 3 2022-09-23
# 4 2022-09-22
# 5 2022-09-22
# 6 2022-09-22
# 7 2022-09-22
# 8 2022-09-22
# 9 2022-09-21

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **DIRECT SAVED DATA**

# %%
'''
import pandas as pd
path = '/content/drive/MyDrive/Colab Notebooks/news_final.csv'
df = pd.read_csv(path)
df.drop(['text'],axis =1)
'''
# Out:
# "\nimport pandas as pd\npath = '/content/drive/MyDrive/Colab Notebooks/news_final.csv'\ndf = pd.read_csv(path)\ndf.drop(['text'],axis =1)\n"

# %%
# import pandas as pd
# path  = '/content/drive/MyDrive/Colab Notebooks/news_40k'
# df = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-70-1c4632b60f5c> in <cell line: 3>()
#       1 import pandas as pd
#       2 path  = '/content/drive/MyDrive/Colab Notebooks/news_40k'
# ----> 3 df = pd.read_csv(path)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946     kwds.update(kwds_defaults)
#     947
# --> 948     return _read(filepath_or_buffer, kwds)
#     949
#     950
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     # Create the parser.
# --> 611     parser = TextFileReader(filepath_or_buffer, **kwds)
#     612
#     613     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1446
#    1447         self.handles: IOHandles | None = None
# -> 1448         self._engine = self._make_engine(f, self.engine)
#    1449
#    1450     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1703                 if "b" not in mode:
#    1704                     mode += "b"
# -> 1705             self.handles = get_handle(
#    1706                 f,
#    1707                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     861         if ioargs.encoding and "b" not in ioargs.mode:
#     862             # Encoding
# --> 863             handle = open(
#     864                 handle,
#     865                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/news_40k'

# %%
shutil.copy('news_classification.csv','/content/drive/MyDrive/Colab Notebooks/news_classification.csv')
# Out:
# '/content/drive/MyDrive/Colab Notebooks/news_classification.csv'

# %%
df['text'] = df[['headline','short_description']].agg(' '.join, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-56bf8a8648c8> in <cell line: 1>()
# ----> 1 df['text'] = df[['headline','short_description']].agg(' '.join, axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3897             if is_iterator(key):
#    3898                 key = list(key)
# -> 3899             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3900
#    3901         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6113             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6114
# -> 6115         self._raise_if_missing(keyarr, indexer, axis_name)
#    6116
#    6117         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6174                 if use_interval_msg:
#    6175                     key = list(key)
# -> 6176                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177
#    6178             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['headline', 'short_description'], dtype='object')] are in the [columns]"

# %%
df.head(10)
# Out:
#      category                                               text
# 0       CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1  WORLD NEWS  South Korean President Meets North Korea's Kim...
# 2    POLITICS  Trump's Crackdown On Immigrant Parents Puts Mo...
# 3    POLITICS  'Trump's Son Should Be Concerned': FBI Obtaine...
# 4    POLITICS  Edward Snowden: There's No One Trump Loves Mor...
# 5    POLITICS  Booyah: Obama Photographer Hilariously Trolls ...
# 6    POLITICS  Ireland Votes To Repeal Abortion Amendment In ...
# 7    POLITICS  Ryan Zinke Looks To Reel Back Some Critics Wit...
# 8    POLITICS  Trump's Scottish Golf Resort Pays Women Signif...
# 9  WORLD NEWS  North Korea Still Open To Talks After Trump Ca...

# %%
delete_list = ["authors","link","date","headline","short_description"]
for x in delete_list:
  del df[x]
delete_row_list = ["EDUCATION","ARTS","CRIME","POLITICS","WORLD NEWS"]
for x in df["category"]:
  if x not in delete_row_list:
    df.drop(df.index[(df["category"] == x)],axis=0,inplace=True)

# %%
df.to_csv('news_40k.csv', encoding='utf-8', index=False)
shutil.copy('news_40k.csv','/content/drive/MyDrive/Colab Notebooks/news40k.csv')
# Out:
# '/content/drive/MyDrive/Colab Notebooks/news40k.csv'

# %%
#df= df.groupby('category').head(500)

# %%
df.shape
# Out:
# (44986, 2)

# %%
df.duplicated()
# Out:
# 7         False
# 9         False
# 10        False
# 11        False
# 12        False
#           ...
# 207483    False
# 207545    False
# 208133    False
# 208134    False
# 208213    False
# Length: 44986, dtype: bool

# %%
df.drop_duplicates(keep=False,inplace=True)

# %%
df.shape
# Out:
# (44940, 2)

# %%
df = df.sort_values(by=["category"])

# %%
print(df["category"].unique())
# Out:
# ['ARTS' 'CRIME' 'EDUCATION' 'POLITICS' 'WORLD NEWS']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44940 entries, 106943 to 7
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  44940 non-null  object
#  1   text      44940 non-null  object
# dtypes: object(2)
# memory usage: 1.0+ MB

# %%
#making copy of dataframe
mf = df
mf.shape
#['ARTS' 'CRIME' 'EDUCATION' 'POLITICS' 'WORLD NEWS']
# Out:
# (44940, 2)

# %% [markdown]
# **SPLITTING DATA**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(mf['text'], mf['category'],test_size=0.2,random_state = 10)

# %%
print("shape of original dataset :", mf.shape)
print("shape of input - training set", x_train.shape)
print("shape of output - training set", y_train.shape)
print("shape of input - testing set", x_test.shape)
print("shape of output - testing set", y_test.shape)
y_train.unique()
# Out:
# shape of original dataset : (44940, 2)
# shape of input - training set (35952,)
# shape of output - training set (35952,)
# shape of input - testing set (8988,)
# shape of output - testing set (8988,)
# array(['POLITICS', 'ARTS', 'EDUCATION', 'WORLD NEWS', 'CRIME'],
#       dtype=object)

# %% [markdown]
# **RECORDS AVAILABLE**

# %%
import matplotlib.pyplot as plt
count = y_train.value_counts()
count.plot.bar()
plt.ylabel('Number of records')
plt.xlabel('category')
plt.show()

# %%
pip install scikit-plot
# Out:
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.5.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.13.1)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Installing collected packages: scikit-plot
# Successfully installed scikit-plot-0.3.7

# %%
import spacy
from spacy import displacy
from  spacy.lang.en.stop_words import STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer
import en_core_web_sm
import string
import nltk

# %%
nlp = spacy.load('en_core_web_sm')

# %%
stopwords = list(STOP_WORDS)
print(stopwords[:100])
# Out:
# ['she', 'take', 'can', 'ours', 'name', 'whence', 'third', 'least', 'anyone', 'ever', 'due', 'hereafter', 'am', 'hers', 'throughout', 're', 'had', 'nobody', 'too', 'between', 'done', '’s', 'that', 'hence', 'whose', 'other', 'it', 'so', "'s", 'five', 'thereby', 'these', 'further', 'here', 'else', 'keep', 'more', '’re', 'out', 'although', 'only', 'becoming', 'herself', 'less', 'within', 'hereby', 'four', 'were', 'several', 'wherein', "n't", 'himself', 'will', 'twenty', 'became', 'nine', 'very', 'using', 'former', 'all', 'along', 'me', 'anything', 'n‘t', 'anyhow', 'hereupon', 'sometime', 'therein', 'used', 'because', 'whereupon', 'eight', 'fifty', 'various', 'yourself', 'nevertheless', '’ll', 'almost', '’ve', 'neither', 'what', 'into', 'now', 'where', 'full', 'why', 'own', 'none', 'noone', 'give', 'once', 'amongst', 'thus', 'see', 'above', 'sometimes', 'otherwise', 'becomes', 'via', 'much']

# %%
# Remove / and - from punctuations for dates
punctuations = string.punctuation
print(punctuations)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# **convert to tokens**

# %%
# Function to tokenise the text
def tokeniser(sentence):

    # Process the text
    doc = nlp(sentence)
    print(doc)

    # Rule 1
    # Convert tokens to lemma form for all except '-PRON-'
    # Remember (from SpaCy introduction) : Tokens like I, my, me were represented as '-PRON-' by lemma attribute
    tokens = [ token.lemma_.lower().strip() if token.lemma_ != "-PRON-" else token.lower_ for token in doc ]

    # Rule 2
    # Remove stop words and punctuation
    tokens = [ token for token in tokens if token not in stopwords and token not in punctuations ]
    print(tokens)
    return tokens

# %%
tfvectorizer = TfidfVectorizer(tokenizer = tokeniser)

# %%
df.isna().sum()
# Out:
# category    0
# text        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (44940, 2)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
classifier_NB = MultinomialNB()

# %%
from sklearn.pipeline import Pipeline

# %%
# Create the  pipeline to clean, tokenize, vectorize, and classify using"Count Vectorizor"
# Multiple models can be added to the Pipeline object to be executed in sequence.
model_pipe_NB = Pipeline( [ ('vectorizer', tfvectorizer),
                         ('classifier', classifier_NB) ] )

# %% [markdown]
# Fit the model

# %%
model_pipe_NB.fit(x_train.values.astype('U'),y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# ['federal', 'agency', 'stop', 'enforce', 'key', 'trump', 'travel', 'ban', 'court', 'order', 'president', 'personally', 'attack', 'federal', 'judge', 'issue', 'temporary', 'restraining', 'order']
# democrats push arne duncan to aid defrauded for-profit college students pressure is mounting on the education secretary to relieve defrauded student loan borrowers of their debts.
# ['democrats', 'push', 'arne', 'duncan', 'aid', 'defraud', 'profit', 'college', 'student', 'pressure', 'mount', 'education', 'secretary', 'relieve', 'defraud', 'student', 'loan', 'borrower', 'debt']
# israel searches for attackers who killed 3 in mass stabbing near tel aviv the stabbing comes as israeli-palestinian tensions were already heightened by violence at a major holy site in jerusalem sacred to jews and muslims.
# ['israel', 'search', 'attacker', 'kill', '3', 'mass', 'stabbing', 'near', 'tel', 'aviv', 'stabbing', 'come', 'israeli', 'palestinian', 'tension', 'heighten', 'violence', 'major', 'holy', 'site', 'jerusalem', 'sacred', 'jews', 'muslim']
# washington state is low on weed for retail marijuana debut
# ['washington', 'state', 'low', 'weed', 'retail', 'marijuana', 'debut']
# in un speech, pope calls for a meaningful commitment in paris "solemn commitments" are necessary steps, but are "not enough," francis tells the u.n.
# ['un', 'speech', 'pope', 'meaningful', 'commitment', 'paris', 'solemn', 'commitment', 'necessary', 'step', 'francis', 'tell', 'u.n']
# white house to fbi director: no, viral videos aren't causing crime james comey continues to argue the "ferguson effect" is fueling the crime surge.
# ['white', 'house', 'fbi', 'director', 'viral', 'video', 'cause', 'crime', 'james', 'comey', 'continue', 'argue', 'ferguson', 'effect', 'fuel', 'crime', 'surge']
# 10 reasons you should care about d.c. voting rights as a former d.c. resident who is now living fully represented in california, i am surprised by the indifference that exists to the plight of washington's 658,893 residents who are heavily taxes yet have no voting representation in congress. it seems maybe we have become too comfortable with this denial of liberty.
# ['10', 'reason', 'care', 'd.c', 'voting', 'right', 'd.c', 'resident', 'live', 'fully', 'represent', 'california', 'surprise', 'indifference', 'exist', 'plight', 'washington', '658,893', 'resident', 'heavily', 'taxis', 'voting', 'representation', 'congress', 'maybe', 'comfortable', 'denial', 'liberty']
# obama can win a huge victory in the fight on his immigration executive orders... but only if he does it right president obama is soon to issue executive orders on immigration.  to score a huge victory in the inevitable political battle, however, he has to orchestrate it for maximum impact.
# ['obama', 'win', 'huge', 'victory', 'fight', 'immigration', 'executive', 'order', '...', 'right', 'president', 'obama', 'soon', 'issue', 'executive', 'order', 'immigration', 'score', 'huge', 'victory', 'inevitable', 'political', 'battle', 'orchestrate', 'maximum', 'impact']
# how about four new scalias on the supreme court trump didn't publicly drop scalia's name at the convention solely because he considered him the judge with the right stuff. it was the one person that he knew, above all others, was considered a demigod among party ultra-conservatives, pro-lifers and evangelicals.
# ['new', 'scalias', 'supreme', 'court', 'trump', 'publicly', 'drop', 'scalia', 'convention', 'solely', 'consider', 'judge', 'right', 'stuff', 'person', 'know', 'consider', 'demigod', 'party', 'ultra', 'conservative', 'pro', 'lifer', 'evangelical']
# join huffpost for our post-debate coverage we'll be picking apart all three hours of the gop debates.
# ['join', 'huffpost', 'post', 'debate', 'coverage', 'pick', 'apart', 'hour', 'gop', 'debate']
# democratic electoral death spiral: a solution by deepak pateriya and dorian warren there has already been a lot of talk among pundits this year about the potential for
# ['democratic', 'electoral', 'death', 'spiral', 'solution', 'deepak', 'pateriya', 'dorian', 'warren', 'lot', 'talk', 'pundit', 'year', 'potential']
# lexington mayor announces plans to relocate confederate statues amid charlottesville violence "the tragic events in charlottesville today have accelerated the announcement i intended to make next week."
# ['lexington', 'mayor', 'announce', 'plan', 'relocate', 'confederate', 'statue', 'amid', 'charlottesville', 'violence', 'tragic', 'event', 'charlottesville', 'today', 'accelerate', 'announcement', 'intend', 'week']
# darrell issa retiring from congress the former house oversight committee chairman was first elected to congress in 2000.
# ['darrell', 'issa', 'retire', 'congress', 'house', 'oversight', 'committee', 'chairman', 'elect', 'congress', '2000']
# companies face pressure to bail on republican convention donald trump's racism might be bad for branding.
# ['company', 'face', 'pressure', 'bail', 'republican', 'convention', 'donald', 'trump', 'racism', 'bad', 'branding']
# why schools are flooded with threats after mass shootings the arrest of dozens of students since the florida massacre spotlights a mental health epidemic.
# ['school', 'flood', 'threat', 'mass', 'shooting', 'arrest', 'dozen', 'student', 'florida', 'massacre', 'spotlight', 'mental', 'health', 'epidemic']
# 2 koreas make history marching under unified flag in olympics opener the nations, split by war, are using the winter games as an opportunity to seek a rapprochement.
# ['2', 'korea', 'history', 'marching', 'unified', 'flag', 'olympic', 'opener', 'nation', 'split', 'war', 'use', 'winter', 'game', 'opportunity', 'seek', 'rapprochement']
# white nationalist calls trump's denouncement of hate groups 'kumbaya nonsense' "i just don’t take him seriously ... it sounded so hollow and vapid,” richard spencer says.
# ['white', 'nationalist', 'trump', 'denouncement', 'hate', 'group', 'kumbaya', 'nonsense', 'seriously', '...', 'sound', 'hollow', 'vapid', 'richard', 'spencer']
# senator chris murphy is not the 'elizabeth warren of foreign policy' on october 6, the center on national security at fordham university school of law hosted sen. chris murphy (d-ct) for a discussion
# ['senator', 'chris', 'murphy', 'elizabeth', 'warren', 'foreign', 'policy', 'october', '6', 'center', 'national', 'security', 'fordham', 'university', 'school', 'law', 'host', 'sen', 'chris', 'murphy', 'd', 'ct', 'discussion']
# cyril ramaphosa, south africa's great negotiator, elected president ramaphosa has fulfilled his long-held ambition to lead the country.
# ['cyril', 'ramaphosa', 'south', 'africa', 'great', 'negotiator', 'elect', 'president', 'ramaphosa', 'fulfil', 'long', 'hold', 'ambition', 'lead', 'country']
# paul ryan says he is 'not ready' to endorse donald trump yet "i’m just not ready to do that at this point. i’m not there yet."
# ['paul', 'ryan', 'ready', 'endorse', 'donald', 'trump', 'ready', 'point']
# newt gingrich: mayors pander to black citizens by removing statues "they are ... doing something that meets current demagogic needs," he told fox news.
# ['newt', 'gingrich', 'mayor', 'pander', 'black', 'citizen', 'remove', 'statue', '...', 'meet', 'current', 'demagogic', 'need', 'tell', 'fox', 'news']
# a portrait of millennial artist nguyễn chi nguyễn is at a sensitive juncture in her life, one that finds her looking to the past for both forgiveness and permission so she can forge a future free from regret. but in doing so she's already claimed a new, divergent path.
# ['portrait', 'millennial', 'artist', 'nguyễn', 'chi', 'nguyễn', 'sensitive', 'juncture', 'life', 'find', 'look', 'past', 'forgiveness', 'permission', 'forge', 'future', 'free', 'regret', 'claim', 'new', 'divergent', 'path']
# missing kansas newborn found in texas after mother's killing two people were taken into custody at the dallas home where the baby was found.
# ['miss', 'kansas', 'newborn', 'find', 'texas', 'mother', 'kill', 'people', 'custody', 'dallas', 'home', 'baby', 'find']
# mcconnell cuts off elizabeth warren for criticizing sessions, senate gop silences her warren was reading a 1986 letter by coretta scott king about sessions.
# ['mcconnell', 'cut', 'elizabeth', 'warren', 'criticize', 'session', 'senate', 'gop', 'silence', 'warren', 'read', '1986', 'letter', 'coretta', 'scott', 'king', 'session']
# woman who laughed at jeff sessions could face jail time this week the government argues that the jury that convicted a code pink protester may have believed her laugh "was a deliberate disruption” and “intentional.”
# ['woman', 'laugh', 'jeff', 'session', 'face', 'jail', 'time', 'week', 'government', 'argue', 'jury', 'convict', 'code', 'pink', 'protester', 'believe', 'laugh', 'deliberate', 'disruption', 'intentional']
# former top intelligence chiefs: trump being 'played' by putin “i think mr. putin is very clever in terms of playing to mr. trump’s interest in being flattered,” former cia director john brennan said
# ['intelligence', 'chief', 'trump', 'play', 'putin', 'think', 'mr', 'putin', 'clever', 'term', 'play', 'mr', 'trump', 'interest', 'flatter', 'cia', 'director', 'john', 'brennan']
# gop congressman complains women are 'in my grill' over obamacare repeal "god forbid women of the 7th district should have an opinion that they want to tell their congressman," one of his constituents said.
# ['gop', 'congressman', 'complain', 'woman', 'grill', 'obamacare', 'repeal', 'god', 'forbid', 'woman', '7th', 'district', 'opinion', 'want', 'tell', 'congressman', 'constituent']
# gaza-israel border falls quiet as ceasefire takes hold egypt mediated the ceasefire and put a halt to one of the most serious spates of cross-border clashes in months.
# ['gaza', 'israel', 'border', 'fall', 'quiet', 'ceasefire', 'hold', 'egypt', 'mediate', 'ceasefire', 'halt', 'spate', 'cross', 'border', 'clash', 'month']
# there's a diploma for that i know the students worked hard, but perhaps class of 2015 shouldn't refer to any student who finished any grade this year. let's save the pomp and circumstance for just one very special circumstance: the day a person is actually awarded her hard-earned degree.
# ['diploma', 'know', 'student', 'work', 'hard', 'class', '2015', 'refer', 'student', 'finish', 'grade', 'year', 'let', 'save', 'pomp', 'circumstance', 'special', 'circumstance', 'day', 'person', 'actually', 'award', 'hard', 'earn', 'degree']
# health risks don't make for a bad president rumors about clinton's health highlight trump's growing desperation.
# ['health', 'risk', 'bad', 'president', 'rumor', 'clinton', 'health', 'highlight', 'trump', 'grow', 'desperation']
# baltimore cop's defense: it wasn’t safe to buckle freddie gray’s seatbelt although a department rule mandated buckling up suspects, an attorney for a cop indicted in gray's death said there's "always discretion for officer safety."
# ['baltimore', 'cop', 'defense', 'safe', 'buckle', 'freddie', 'gray', 'seatbelt', 'department', 'rule', 'mandate', 'buckle', 'suspect', 'attorney', 'cop', 'indict', 'gray', 'death', 'discretion', 'officer', 'safety']
# good guys with guns? good guys stopping bad guys is a myth perpetuated in movies and television. the best chance of stopping a bad guy with a gun is good policy that makes it tougher to get one.
# ['good', 'guy', 'gun', 'good', 'guy', 'stop', 'bad', 'guy', 'myth', 'perpetuate', 'movie', 'television', 'good', 'chance', 'stop', 'bad', 'guy', 'gun', 'good', 'policy', 'tough']
# this is the plane that will be the new air force one
# ['plane', 'new', 'air', 'force']
# critique against trump on iran deal grows; no new negotiations possible united nations – if secretary of state rex tillerson is correct, the agreement to curb iran’s nuclear ambitions has to be
# ['critique', 'trump', 'iran', 'deal', 'grow', 'new', 'negotiation', 'possible', 'united', 'nation', '–', 'secretary', 'state', 'rex', 'tillerson', 'correct', 'agreement', 'curb', 'iran', 'nuclear', 'ambition']
# james clapper calls trump's bin laden criticism a 'slam at the intelligence community' the president thinks retired navy adm. william mcraven should have brought osama bin laden to justice sooner.
# ['james', 'clapper', 'trump', 'bin', 'laden', 'criticism', 'slam', 'intelligence', 'community', 'president', 'think', 'retired', 'navy', 'adm', 'william', 'mcraven', 'bring', 'osama', 'bin', 'laden', 'justice', 'soon']
# chilling report details myanmar's horrific campaign against rohingya minority more than 530,000 rohingyas have fled the country in less than two months.
# ['chilling', 'report', 'detail', 'myanmar', 'horrific', 'campaign', 'rohingya', 'minority', '530,000', 'rohingyas', 'flee', 'country', 'month']
# on belief vs. identity: letter to a young north american muslim remember, your religious beliefs are not you. they are simply part of the medium you were cultured in when you were raised.
# ['belief', 'vs.', 'identity', 'letter', 'young', 'north', 'american', 'muslim', 'remember', 'religious', 'belief', 'simply', 'medium', 'culture', 'raise']
# british woman dies after exposure to nerve agent, authorities say dawn sturgess, 44, died of the same novichok toxin used on a former russian spy four months ago.
# ['british', 'woman', 'die', 'exposure', 'nerve', 'agent', 'authority', 'dawn', 'sturgess', '44', 'die', 'novichok', 'toxin', 'use', 'russian', 'spy', 'month', 'ago']
# fox news contributor jehmu greene announces candidacy to lead dnc the texan democrat is the seventh candidate to join the hotly contested chairmanship race.
# ['fox', 'news', 'contributor', 'jehmu', 'greene', 'announce', 'candidacy', 'lead', 'dnc', 'texan', 'democrat', 'seventh', 'candidate', 'join', 'hotly', 'contest', 'chairmanship', 'race']
# donald trump slams virginia gop for instituting loyalty pledge "it begins," the republican presidential hopeful warned.
# ['donald', 'trump', 'slams', 'virginia', 'gop', 'institute', 'loyalty', 'pledge', 'begin', 'republican', 'presidential', 'hopeful', 'warn']
# conservatives, long used to bashing the speaker, praise paul ryan some also say they want to give credit where credit is due -- to themselves.
# ['conservative', 'long', 'use', 'bash', 'speaker', 'praise', 'paul', 'ryan', 'want', 'credit', 'credit', '--']
# shaq says he's planning to run for sheriff “this is not about politics. this is about bringing people closer together," he said.
# ['shaq', 'plan', 'run', 'sheriff', 'politic', 'bring', 'people', 'close']
# tuesday's morning email: house republicans to release their secret memo attacking russia probe and the state of the union is tonight.
# ['tuesday', 'morning', 'email', 'house', 'republicans', 'release', 'secret', 'memo', 'attack', 'russia', 'probe', 'state', 'union', 'tonight']
# white house warns syria against launching another chemical weapons attack “if ... mr. assad conducts another mass murder attack using chemical weapons, he and his military will pay a heavy price."
# ['white', 'house', 'warn', 'syria', 'launch', 'chemical', 'weapon', 'attack', '...', 'mr', 'assad', 'conduct', 'mass', 'murder', 'attack', 'use', 'chemical', 'weapon', 'military', 'pay', 'heavy', 'price']
# the trump drill team's terrible offshore plan no one expected good news from the trump administration’s first proposed plan for offshore drilling, but this? the malicious
# ['trump', 'drill', 'team', 'terrible', 'offshore', 'plan', 'expect', 'good', 'news', 'trump', 'administration', 'propose', 'plan', 'offshore', 'drilling', 'malicious']
# man who scaled part of trump tower using suction cups pulled inside by police the human fly drew hundreds of onlookers.
# ['man', 'scale', 'trump', 'tower', 'use', 'suction', 'cup', 'pull', 'inside', 'police', 'human', 'fly', 'draw', 'onlooker']
# extremism report puts saudi arabia and british pm may on the spot, strengthens qatar in gulf crisis by james m. dorsey a report charging saudi arabia with funding extremism in britain puts both the kingdom and prime minister
# ['extremism', 'report', 'saudi', 'arabia', 'british', 'pm', 'spot', 'strengthen', 'qatar', 'gulf', 'crisis', 'james', 'm.', 'dorsey', 'report', 'charge', 'saudi', 'arabia', 'fund', 'extremism', 'britain', 'kingdom', 'prime', 'minister']
# ted cruz on islamic state militants: 'take them out'
# ['ted', 'cruz', 'islamic', 'state', 'militant']
# my exchange with alt-right leader richard spencer i recently received an email from spencer in response to an op-ed i wrote in april.
# ['exchange', 'alt', 'right', 'leader', 'richard', 'spencer', 'recently', 'receive', 'email', 'spencer', 'response', 'op', 'ed', 'write', 'april']
# an antidote to trumpcare cross-posted from tomdispatch.com over the years, ann jones has confronted some of the most daunting and depressing issues
# ['antidote', 'trumpcare', 'cross', 'post', 'tomdispatch.com', 'year', 'ann', 'jones', 'confront', 'daunting', 'depressing', 'issue']
# sen. jeff merkley stages all-night protest on senate floor against gorsuch nomination "this assault on our democracy demands as robust a resistance as we can possibly mount."
# ['sen', 'jeff', 'merkley', 'stage', 'night', 'protest', 'senate', 'floor', 'gorsuch', 'nomination', 'assault', 'democracy', 'demand', 'robust', 'resistance', 'possibly', 'mount']
# trump smears kirsten gillibrand as a 'flunky' who 'would do anything' for campaign money the new york senator called on trump to resign after several women asked congress to investigate their stories.
# ['trump', 'smear', 'kirsten', 'gillibrand', 'flunky', 'campaign', 'money', 'new', 'york', 'senator', 'trump', 'resign', 'woman', 'ask', 'congress', 'investigate', 'story']
# police hunting for baby allegedly thrown in creek by mom police are scouring a creek outside myrtle beach, sc, for a missing infant who disappeared under suspicious circumstances
# ['police', 'hunting', 'baby', 'allegedly', 'throw', 'creek', 'mom', 'police', 'scour', 'creek', 'outside', 'myrtle', 'beach', 'sc', 'miss', 'infant', 'disappear', 'suspicious', 'circumstance']
# california’s prop. 64 isn’t just marijuana legalization. it’s meaningful criminal justice reform. in two weeks, california voters will decide on proposition 64, or the adult use of marijuana act (auma). if passed, auma
# ['california', 'prop', '64', 'marijuana', 'legalization', '’', 'meaningful', 'criminal', 'justice', 'reform', 'week', 'california', 'voter', 'decide', 'proposition', '64', 'adult', 'use', 'marijuana', 'act', 'auma', 'pass', 'auma']
# u.s. v. texas: how the supreme court got tangled in immigration law something is wrong when supreme court justices wrestle this way with legal concepts. the problem is clearly not they. the law, regulations, and policies are the problem, as is the inertia that keeps them that way.
# ['u.s', 'v.', 'texas', 'supreme', 'court', 'tangle', 'immigration', 'law', 'wrong', 'supreme', 'court', 'justice', 'wrestle', 'way', 'legal', 'concept', 'problem', 'clearly', 'law', 'regulation', 'policy', 'problem', 'inertia', 'way']
# huffpollster: most americans don’t think donald trump has a mandate to govern about half are unhappy with the election’s outcome.
# ['huffpollster', 'americans', 'think', 'donald', 'trump', 'mandate', 'govern', 'half', 'unhappy', 'election', 'outcome']
# biden at un to call russian war an affront to body's charter white house officials say the crux of the president's visit to the u.n. this year will be a full-throated condemnation of russia and its brutal war.
# ['biden', 'un', 'russian', 'war', 'affront', 'body', 'charter', 'white', 'house', 'official', 'crux', 'president', 'visit', 'u.n', 'year', 'throate', 'condemnation', 'russia', 'brutal', 'war']
# more allegations of deception surface in orange county informant scandal a public defender has accused the county sheriff department of intentionally hiding and possibly destroying evidence.
# ['allegation', 'deception', 'surface', 'orange', 'county', 'informant', 'scandal', 'public', 'defender', 'accuse', 'county', 'sheriff', 'department', 'intentionally', 'hide', 'possibly', 'destroy', 'evidence']
# some thoughts of secret voters -- did our labels keep them hidden? what about the other trump supporters?
# ['thought', 'secret', 'voter', '--', 'label', 'hide', 'trump', 'supporter']
# michigan teen believes shirt was left on her car windshield as a trap police said they "can’t definitively say whether kidnapping or abduction was the end goal."
# ['michigan', 'teen', 'believe', 'shirt', 'leave', 'car', 'windshield', 'trap', 'police', 'definitively', 'kidnapping', 'abduction', 'end', 'goal']
# man who carjacked woman in labor gets 5 years a gun was pointed at her as she went into labor.
# ['man', 'carjack', 'woman', 'labor', '5', 'year', 'gun', 'point', 'labor']
# republican senators call trump's debate performance 'interesting' others avoided answering questions about it, particularly their nominee's fat-shaming of a miss universe.
# ['republican', 'senator', 'trump', 'debate', 'performance', 'interesting', 'avoid', 'answer', 'question', 'particularly', 'nominee', 'fat', 'shaming', 'miss', 'universe']
# border militia co-founder convicted of child molestation in arizona an arizona jury on wednesday convicted the co-founder of a border militia group of molesting a 5-year-old girl but acquitted
# ['border', 'militia', 'co', 'founder', 'convict', 'child', 'molestation', 'arizona', 'arizona', 'jury', 'wednesday', 'convict', 'co', 'founder', 'border', 'militia', 'group', 'molest', '5', 'year', 'old', 'girl', 'acquit']
# california climate bills could set a high bar for the rest of the country the state would be set up to reduce emissions 80 percent by 2050.
# ['california', 'climate', 'bill', 'set', 'high', 'bar', 'rest', 'country', 'state', 'set', 'reduce', 'emission', '80', 'percent', '2050']
# world leaders condemn trump for withdrawing from iran nuclear deal france, the u.k. and germany had attempted a last-ditch push to get trump to change his mind in recent weeks.
# ['world', 'leader', 'condemn', 'trump', 'withdraw', 'iran', 'nuclear', 'deal', 'france', 'u.k', 'germany', 'attempt', 'ditch', 'push', 'trump', 'change', 'mind', 'recent', 'week']
# san francisco passes landmark parental leave law san francisco — san francisco on tuesday became the first city in the united states to approve six weeks of fully paid leave
# ['san', 'francisco', 'pass', 'landmark', 'parental', 'leave', 'law', 'san', 'francisco', '—', 'san', 'francisco', 'tuesday', 'city', 'united', 'states', 'approve', 'week', 'fully', 'pay', 'leave']
# donald trump has 'no intention' of releasing his tax returns, treasury secretary says "i think the american population has plenty of information on his taxes."
# ['donald', 'trump', 'intention', 'release', 'tax', 'return', 'treasury', 'secretary', 'think', 'american', 'population', 'plenty', 'information', 'taxis']
# putin's view of trump: a pushover, a weaker version of neville chamberlain the latest joke in our absurd presidential campaign is that russian president vladimir putin sees donald trump as a strong leader.  this is causing belly-laughs in the kremlin.
# ['putin', 'view', 'trump', 'pushover', 'weak', 'version', 'neville', 'chamberlain', 'late', 'joke', 'absurd', 'presidential', 'campaign', 'russian', 'president', 'vladimir', 'putin', 'donald', 'trump', 'strong', 'leader', 'cause', 'belly', 'laugh', 'kremlin']
# scott walker gives up fight to not call wisconsin special elections three different judges rejected walker's appeal to hold off on the votes until november.
# ['scott', 'walker', 'fight', 'wisconsin', 'special', 'election', 'different', 'judge', 'reject', 'walker', 'appeal', 'hold', 'vote', 'november']
# mike pence denies he's considering abandoning trump nothing to see here, folks.
# ['mike', 'pence', 'deny', 'consider', 'abandon', 'trump', 'folk']
# espn host committed 'fireable offense' with trump 'white supremacist' tweet: white house aide ″i think that’s one of the more outrageous comments that anyone could make," press secretary sarah huckabee sanders said.
# ['espn', 'host', 'commit', 'fireable', 'offense', 'trump', 'white', 'supremacist', 'tweet', 'white', 'house', 'aide', '″i', 'think', '’', 'outrageous', 'comment', 'press', 'secretary', 'sarah', 'huckabee', 'sander']
# how this brazilian city became ground zero for the amazon's deforestation crisis rampant corruption, environmental indifference and a thirst for growth helped brazil ignore a brewing crisis in altamira.
# ['brazilian', 'city', 'ground', 'zero', 'amazon', 'deforestation', 'crisis', 'rampant', 'corruption', 'environmental', 'indifference', 'thirst', 'growth', 'help', 'brazil', 'ignore', 'brewing', 'crisis', 'altamira']
# obama shakes hands with raul castro ahead of historic meeting
# ['obama', 'shake', 'hand', 'raul', 'castro', 'ahead', 'historic', 'meeting']
# the path to healing in the middle east relations between nations and cultures have some parallel dynamics. when we feel threatened, dishonored or wronged, our natural tendency is to escalate and worsen situations based on the simple logic of our self-preservationist biology.
# ['path', 'healing', 'middle', 'east', 'relation', 'nation', 'culture', 'parallel', 'dynamic', 'feel', 'threatened', 'dishonor', 'wrong', 'natural', 'tendency', 'escalate', 'worsen', 'situation', 'base', 'simple', 'logic', 'self', 'preservationist', 'biology']
# mitch mcconnell wants to put off a real budget even longer the senate majority leader is jockeying for position with trump’s white house.
# ['mitch', 'mcconnell', 'want', 'real', 'budget', 'long', 'senate', 'majority', 'leader', 'jockey', 'position', 'trump', 'white', 'house']
# exclusive: sheriff's office cuts off jailhouse interview after deadly raid on georgia home
# ['exclusive', 'sheriff', 'office', 'cut', 'jailhouse', 'interview', 'deadly', 'raid', 'georgia', 'home']
# this state just did something good for transgender people several other states this week passed laws that could discriminate against transgender people.
# ['state', 'good', 'transgender', 'people', 'state', 'week', 'pass', 'law', 'discriminate', 'transgender', 'people']
# china read emails of top u.s. officials china's cyber spies have accessed the private emails of "many" top obama administration officials, according to a senior
# ['china', 'read', 'email', 'u.s', 'officials', 'china', 'cyber', 'spy', 'access', 'private', 'email', 'obama', 'administration', 'official', 'accord', 'senior']
# senate democrats boycott key votes on 2 top trump nominees republicans don't have the quorum needed to move forward.
# ['senate', 'democrats', 'boycott', 'key', 'vote', '2', 'trump', 'nominee', 'republicans', 'quorum', 'need', 'forward']
# democrats slam manchin for saying he can't vote for biden's build back better plan “if he doesn’t have the courage to do the right thing ... let him vote no in front of the whole world,” said sen. bernie sanders (i-vt.).
# ['democrats', 'slam', 'manchin', 'vote', 'biden', 'build', 'plan', 'courage', 'right', 'thing', '...', 'let', 'vote', 'world', 'sen', 'bernie', 'sanders', 'vt']
# escaped jail inmate found hiding inside a dishwasher "he took out the racks and made himself a nice cubby hole."
# ['escape', 'jail', 'inmate', 'find', 'hide', 'inside', 'dishwasher', 'rack', 'nice', 'cubby', 'hole']
# group wants special prosecutor in police killing of farmworker
# ['group', 'want', 'special', 'prosecutor', 'police', 'killing', 'farmworker']
# the presidency as performance art is this constant activity is a carefully conceived strategy to distract the public and the press?
# ['presidency', 'performance', 'art', 'constant', 'activity', 'carefully', 'conceive', 'strategy', 'distract', 'public', 'press']
# our message against anti-muslim hate on san bernardino's hallowed ground introduction good morning, and thank you so very, very much for the privilege of speaking to you in peace today away from
# ['message', 'anti', 'muslim', 'hate', 'san', 'bernardino', 'hallowed', 'ground', 'introduction', 'good', 'morning', 'thank', 'privilege', 'speak', 'peace', 'today', 'away']
# hillary clinton is actually doing better with small donors $10.5 million from small donors in february is a big improvement, even if it is still way less than bernie sanders' haul.
# ['hillary', 'clinton', 'actually', 'small', 'donor', '10.5', 'million', 'small', 'donor', 'february', 'big', 'improvement', 'way', 'bernie', 'sanders', 'haul']
# in trump era, democrats and republicans switch sides on states' rights an unexpected twist in one of the country's oldest constitutional debates.
# ['trump', 'era', 'democrats', 'republicans', 'switch', 'state', 'right', 'unexpected', 'twist', 'country', 'old', 'constitutional', 'debate']
# will the u.s. ever win the war in afghanistan? the american consciousness simply has no conception, not even a trumpian illusion, of what “winning” looks like.
# ['u.s', 'win', 'war', 'afghanistan', 'american', 'consciousness', 'simply', 'conception', 'trumpian', 'illusion', 'win', 'look', 'like']
# as mueller closes in, how long will kelly last? it is impossible to believe that trump will not escalate his campaign of vilification of mueller and his associates.
# ['mueller', 'close', 'long', 'kelly', 'impossible', 'believe', 'trump', 'escalate', 'campaign', 'vilification', 'mueller', 'associate']
# tweeters troll corey lewandowski for calling donald trump 'hemingway of twitter' "trump ain't even ernest goes to camp!!!"
# ['tweeter', 'troll', 'corey', 'lewandowski', 'donald', 'trump', 'hemingway', 'twitter', 'trump', 'ernest', 'camp']
# what the democrats need is a defensive president jack hitt: with both parties chronically incapable of settling on a nominee, we prepare to leave south carolina—opting for
# ['democrats', 'need', 'defensive', 'president', 'jack', 'hitt', 'party', 'chronically', 'incapable', 'settle', 'nominee', 'prepare', 'leave', 'south', 'carolina', '—', 'opt']
# judge denies bail to michael slager, former officer charged with murder of walter scott slager has been jailed since april.
# ['judge', 'deny', 'bail', 'michael', 'slager', 'officer', 'charge', 'murder', 'walter', 'scott', 'slager', 'jail', 'april']
# the green party takes itself very seriously, but no one else should even a participation trophy might be out of reach.
# ['green', 'party', 'seriously', 'participation', 'trophy', 'reach']
# our fear of female leadership: the sweeping promise of change is no change at all change isn't what americans wanted; it’s what they’re afraid of.
# ['fear', 'female', 'leadership', 'sweeping', 'promise', 'change', 'change', 'change', 'americans', 'want', '’', 'afraid']
# citing apparent internet hoax, trump insists protester has isis ties “all i know is what’s on the internet.”
# ['cite', 'apparent', 'internet', 'hoax', 'trump', 'insist', 'protester', 'isis', 'tie', 'know', '’', 'internet']
# the us flag must earn the respect of those it disrespected mr. kaepernick has sacrificed by attempting to move us all toward a more perfect union.
# ['flag', 'earn', 'respect', 'disrespect', 'mr', 'kaepernick', 'sacrifice', 'attempt', 'perfect', 'union']
# americans’ respect for police soars to highest point in 50 years, survey finds just last year, people's confidence in their local police was significantly lower.
# ['americans', '’', 'respect', 'police', 'soar', 'high', 'point', '50', 'year', 'survey', 'find', 'year', 'people', 'confidence', 'local', 'police', 'significantly', 'low']
# california rampage shocks those who knew shooters "this was a person who was successful, who had a good job, a good income, a wife and a family. what was he missing in his life?"
# ['california', 'rampage', 'shock', 'know', 'shooter', 'person', 'successful', 'good', 'job', 'good', 'income', 'wife', 'family', 'miss', 'life']
# bernie sanders spent $0 on polling, because really, would it change his mind anyway? “i personally would like to, but i haven’t convinced him yet that we should," says top aide.
# ['bernie', 'sander', 'spend', '0', 'polling', 'change', 'mind', 'personally', 'like', 'convince', 'aide']
# trump hits new polling low i originally wrote “trump hits new low” as this article’s title, but then realized that it was far too generic a headline
# ['trump', 'hit', 'new', 'polling', 'low', 'originally', 'write', 'trump', 'hit', 'new', 'low', 'article', 'title', 'realize', 'far', 'generic', 'headline']
# twitter users skewer trump's bizarre rant about '6g' technology one person also asked for time machines and robots that "do for chores for us."
# ['twitter', 'user', 'skewer', 'trump', 'bizarre', 'rant', '6', 'g', 'technology', 'person', 'ask', 'time', 'machine', 'robot', 'chore']
# why obamacare premiums will probably rise more quickly next year
# ['obamacare', 'premium', 'probably', 'rise', 'quickly', 'year']
# getting totally bushed i'm beginning to think that contemplative, analytical thinking is not an inherited trait handed down to the bush children.
# ['getting', 'totally', 'bush', 'begin', 'think', 'contemplative', 'analytical', 'thinking', 'inherited', 'trait', 'hand', 'bush', 'child']
# loretta lynch says there's 'no data' to support the ferguson effect the attorney general said the discussion about policing only makes us all safer.
# ['loretta', 'lynch', 'data', 'support', 'ferguson', 'effect', 'attorney', 'general', 'discussion', 'police', 'safe']
# a crooked wall street billionaire is crafting trumponomics hoo boy.
# ['crooked', 'wall', 'street', 'billionaire', 'craft', 'trumponomic', 'hoo', 'boy']
# earthquake in china's sichuan province kills at least 19, injures 247 the 7.0-magnitude temblor struck a remote and mountainous region.
# ['earthquake', 'china', 'sichuan', 'province', 'kill', '19', 'injure', '247', '7.0', 'magnitude', 'temblor', 'strike', 'remote', 'mountainous', 'region']
# senate plans september hearings on health insurance market sen. lamar alexander urged trump to allow payments through september.
# ['senate', 'plan', 'september', 'hearing', 'health', 'insurance', 'market', 'sen', 'lamar', 'alexander', 'urge', 'trump', 'allow', 'payment', 'september']
# south dakota congressional candidate said terrorist attack would help him win primary state sen. neal tapio was the state director for donald trump’s 2016 campaign.
# ['south', 'dakota', 'congressional', 'candidate', 'terrorist', 'attack', 'help', 'win', 'primary', 'state', 'sen', 'neal', 'tapio', 'state', 'director', 'donald', 'trump', '2016', 'campaign']
# maine gov. paul lepage says taking down confederate statues is like removing 9/11 memorial "whether we like it or not, this is what our history is," said the trump-backing republican.
# ['maine', 'gov', 'paul', 'lepage', 'confederate', 'statue', 'like', 'remove', '9/11', 'memorial', 'like', 'history', 'trump', 'republican']
# prologue to my blog
# ['prologue', 'blog']
# the fight between sanders and clinton isn't a purity test. it's a genuine divide over gender and corporate power. elizabeth warren lit the fuse.
# ['fight', 'sander', 'clinton', 'purity', 'test', 'genuine', 'divide', 'gender', 'corporate', 'power', 'elizabeth', 'warren', 'light', 'fuse']
# scott walker is 2016's mitt romney enter scott walker's politics of fear. for the party that rhetorically champions self-reliance, the emphasis on creating fear and despair in the electorate is ironic, but effective. why blame yourself for economic insecurity when you can blame a faceless immigrant plotting to take away your job?
# ['scott', 'walker', '2016', 'mitt', 'romney', 'enter', 'scott', 'walker', 'politic', 'fear', 'party', 'rhetorically', 'champion', 'self', 'reliance', 'emphasis', 'create', 'fear', 'despair', 'electorate', 'ironic', 'effective', 'blame', 'economic', 'insecurity', 'blame', 'faceless', 'immigrant', 'plot', 'away', 'job']
# watch cute kids sing john oliver's song for dc statehood adorable.
# ['watch', 'cute', 'kid', 'sing', 'john', 'oliver', 'song', 'dc', 'statehood', 'adorable']
# scott walker pushes alec 'right to work' bill, divide and conquer comes full circle just weeks ago, the washington post described scott walker as the first "it" candidate of the 2016 presidential races, but after stumbling over "truth," evolution, and whether or not the president is a christian or loves america, walker is getting ready to change the topic.
# ['scott', 'walker', 'pushes', 'alec', 'right', 'work', 'bill', 'divide', 'conquer', 'come', 'circle', 'week', 'ago', 'washington', 'post', 'describe', 'scott', 'walker', 'candidate', '2016', 'presidential', 'race', 'stumble', 'truth', 'evolution', 'president', 'christian', 'love', 'america', 'walker', 'ready', 'change', 'topic']
# california police chief lashes out at dhs over immigration raids what was disguised as a gang bust actually resulted in people being detained due to their immigration status.
# ['california', 'police', 'chief', 'lash', 'dhs', 'immigration', 'raid', 'disguise', 'gang', 'bust', 'actually', 'result', 'people', 'detain', 'immigration', 'status']
# will trump's convention be safe? protesters say they come in peace, and police say they come prepared, but some participants are still skittish.
# ['trump', 'convention', 'safe', 'protester', 'come', 'peace', 'police', 'come', 'prepared', 'participant', 'skittish']
# heath howe tied up daughter to play video games, cops say the girl's mother and a friend found the girl tied up after they returned from a trip to the gym, fox news reports. the mother's
# ['heath', 'howe', 'tie', 'daughter', 'play', 'video', 'game', 'cop', 'girl', 'mother', 'friend', 'find', 'girl', 'tie', 'return', 'trip', 'gym', 'fox', 'news', 'report', 'mother']
# some of our decisions will not be popular. but, our goal is to improve rome air quality. improving air quality in a big city like rome is a goal that will pose a challenge to the habits of every resident of one
# ['decision', 'popular', 'goal', 'improve', 'rome', 'air', 'quality', 'improve', 'air', 'quality', 'big', 'city', 'like', 'rome', 'goal', 'pose', 'challenge', 'habit', 'resident']
# myanmar steps up campaign against rohingya by bulldozing villages: report and the government is building military bases and new villages in their place.
# ['myanmar', 'step', 'campaign', 'rohingya', 'bulldoze', 'village', 'report', 'government', 'build', 'military', 'basis', 'new', 'village', 'place']
# donald trump: police should have taken guns from florida shooter 'whether they had the right or not' trump said a lot of surprising things during a bipartisan meeting with lawmakers on gun control.
# ['donald', 'trump', 'police', 'gun', 'florida', 'shooter', 'right', 'trump', 'lot', 'surprising', 'thing', 'bipartisan', 'meeting', 'lawmaker', 'gun', 'control']
# paul ryan pledges 9/11 bill is all but done just two hurdles remain -- how to bring the bill to a vote and how to pay for it.
# ['paul', 'ryan', 'pledge', '9/11', 'bill', 'hurdle', 'remain', '--', 'bring', 'bill', 'vote', 'pay']
# should washington d.c. have a vote in congress? donald trump is ok with it. trump opposes d.c. statehood, but says "representation would be okay."
# ['washington', 'd.c', 'vote', 'congress', 'donald', 'trump', 'ok', 'trump', 'oppose', 'd.c', 'statehood', 'representation', 'okay']
# trump attacks goodyear after it asks workers to avoid politics on job goodyear has a more than 120-year history in ohio, a battleground state in the presidential election.
# ['trump', 'attack', 'goodyear', 'ask', 'worker', 'avoid', 'politic', 'job', 'goodyear', '120', 'year', 'history', 'ohio', 'battleground', 'state', 'presidential', 'election']
# large rural manufacturers may score higher than urban ones on innovation rural areas may be as innovative as urban ones in some instances. the finding contradicts conventional wisdom that urban
# ['large', 'rural', 'manufacturer', 'score', 'high', 'urban', 'innovation', 'rural', 'area', 'innovative', 'urban', 'instance', 'finding', 'contradict', 'conventional', 'wisdom', 'urban']
# donald trump’s cabinet is on track to be the least experienced in modern history the president-elect may believe that’s a good thing. but governance experts are alarmed.
# ['donald', 'trump', 'cabinet', 'track', 'experience', 'modern', 'history', 'president', 'elect', 'believe', '’', 'good', 'thing', 'governance', 'expert', 'alarmed']
# london breed sworn in as san francisco's first black female mayor breed promised to be a voice for those who grew up in public housing, just like she did.
# ['london', 'breed', 'swear', 'san', 'francisco', 'black', 'female', 'mayor', 'breed', 'promise', 'voice', 'grow', 'public', 'housing', 'like']
# claire mccaskill says she had a cursing problem early in her career the senator said she swore a lot to fit in with the men she worked with.
# ['claire', 'mccaskill', 'cursing', 'problem', 'early', 'career', 'senator', 'swear', 'lot', 'fit', 'man', 'work']
# looking to the feds for help in fighting cybercriminals cybercriminals are unrelenting in their attacks on state and local government computers, and the states are looking to congress
# ['look', 'feds', 'help', 'fight', 'cybercriminal', 'cybercriminal', 'unrelente', 'attack', 'state', 'local', 'government', 'computer', 'state', 'look', 'congress']
# tim murphy’s resignation highlights moral bankruptcy of pro-life movement we've seen this kind of blatant hypocrisy in the past and know it runs much deeper than one man’s scandalous behavior.
# ['tim', 'murphy', 'resignation', 'highlight', 'moral', 'bankruptcy', 'pro', 'life', 'movement', 'kind', 'blatant', 'hypocrisy', 'past', 'know', 'run', 'deep', 'man', 'scandalous', 'behavior']
# to win, democrats don’t need trump voters yesterday, new york times columnist thomas friedman joined the chorus of voices urging the left to try to bring trump voters
# ['win', 'democrat', 'need', 'trump', 'voter', 'yesterday', 'new', 'york', 'times', 'columnist', 'thomas', 'friedman', 'join', 'chorus', 'voice', 'urge', 'left', 'try', 'bring', 'trump', 'voter']
# supreme court to review how florida doles out the death penalty
# ['supreme', 'court', 'review', 'florida', 'dole', 'death', 'penalty']
# inside the nationwide protests against trump's executive order photos show thousands of demonstrators taking to the streets to defend those affected by the travel ban.
# ['inside', 'nationwide', 'protest', 'trump', 'executive', 'order', 'photo', 'thousand', 'demonstrator', 'street', 'defend', 'affect', 'travel', 'ban']
# how dog lovers sparked laws that could save kids in hot cars about 37 children die of heat stroke in cars every year. new laws ensure that bystanders who break car windows to rescue
# ['dog', 'lover', 'spark', 'law', 'save', 'kid', 'hot', 'car', '37', 'child', 'die', 'heat', 'stroke', 'car', 'year', 'new', 'law', 'ensure', 'bystander', 'break', 'car', 'window', 'rescue']
# america is responsible for aleppo's destruction
# ['america', 'responsible', 'aleppo', 'destruction']
# blackhawk army helicopter crashes on golf course, injuring two people “it disappeared behind the tree line, and then we heard a big bang,” a witness said.
# ['blackhawk', 'army', 'helicopter', 'crash', 'golf', 'course', 'injure', 'people', 'disappear', 'tree', 'line', 'hear', 'big', 'bang', 'witness']
# downed jet is the latest element in the syrian powder keg the white house calls it “self-defense,” and russia has responded by threatening to shoot down american planes.
# ['jet', 'late', 'element', 'syrian', 'powder', 'keg', 'white', 'house', 'self', 'defense', 'russia', 'respond', 'threaten', 'shoot', 'american', 'plane']
# rand paul: voter id push is 'dumb,' but the laws are reasonable
# ['rand', 'paul', 'voter', 'd', 'push', 'dumb', 'law', 'reasonable']
# the world bank accidentally left me a voicemail discussing their strategy to downplay rights abuses on june 27 we released a joint report documenting forced and child labor linked to the world bank’s agriculture projects
# ['world', 'bank', 'accidentally', 'leave', 'voicemail', 'discuss', 'strategy', 'downplay', 'right', 'abuse', 'june', '27', 'release', 'joint', 'report', 'documenting', 'force', 'child', 'labor', 'link', 'world', 'bank', 'agriculture', 'project']
# saudi crown prince's claims about gender equality don't add up mohammed bin salman says he's undoing decades of  oppression, but women still lack equal rights.
# ['saudi', 'crown', 'prince', 'claim', 'gender', 'equality', 'add', 'mohammed', 'bin', 'salman', 'undo', 'decade', 'oppression', 'woman', 'lack', 'equal', 'right']
# ceo pay rises to $12.7m even as pandemic ravages economy pay packages rose yet again last year for the ceos of the biggest companies, even though the pandemic sent the economy to its worst quarter on record.
# ['ceo', 'pay', 'rise', '12.7', 'm', 'pandemic', 'ravage', 'economy', 'pay', 'package', 'rise', 'year', 'ceo', 'big', 'company', 'pandemic', 'send', 'economy', 'bad', 'quarter', 'record']
# a top republican makes absurdly contradictory argument about supreme court chuck grassley says voters should decide the next high court nominee, then accuses democrats of playing politics.
# ['republican', 'absurdly', 'contradictory', 'argument', 'supreme', 'court', 'chuck', 'grassley', 'voter', 'decide', 'high', 'court', 'nominee', 'accuse', 'democrat', 'play', 'politic']
# detention push ignites new deportation battles expansion of detention centers to support a trump administration push for more deportations is meeting resistance in some
# ['detention', 'push', 'ignite', 'new', 'deportation', 'battle', 'expansion', 'detention', 'center', 'support', 'trump', 'administration', 'push', 'deportation', 'meet', 'resistance']
# guantanamo defense lawyers in 9/11 trial aren't under fbi investigation, doj tells court
# ['guantanamo', 'defense', 'lawyer', '9/11', 'trial', 'fbi', 'investigation', 'doj', 'tell', 'court']
# 22 states sue fcc for axing net neutrality the legal battle against the federal communications commission has just begun.
# ['22', 'state', 'sue', 'fcc', 'axe', 'net', 'neutrality', 'legal', 'battle', 'federal', 'communications', 'commission', 'begin']
# remembering herb goodwin, judge, baseball buddy and angel, r.i.p. of his father, hamlet says to horatio, "'a was a man, take him for all in all, i shall not look upon his like again." herb goodwin was not my father, whom i love, but herb was an angelic father figure to me, and i know i shall not look upon his like again.
# ['remember', 'herb', 'goodwin', 'judge', 'baseball', 'buddy', 'angel', 'r.i.p', 'father', 'hamlet', 'horatio', 'man', 'shall', 'look', 'like', 'herb', 'goodwin', 'father', 'love', 'herb', 'angelic', 'father', 'figure', 'know', 'shall', 'look', 'like']
# literally what is sarah palin even talking about "you know what i mean?" no, not really.
# ['literally', 'sarah', 'palin', 'talk', 'know', 'mean']
# how conservatives justify poll taxes
# ['conservative', 'justify', 'poll', 'taxis']
# donald trump said women should be punished for getting abortions. they already are. here are 13 ways.
# ['donald', 'trump', 'woman', 'punish', 'abortion', '13', 'way']
# the 15 most bizarre moments from the jodi arias trial (so far) read on to read jodi arias' most bizarre statements: (readers are warned that some of the content is graphic) the 32-year
# ['15', 'bizarre', 'moment', 'jodi', 'arias', 'trial', 'far', 'read', 'read', 'jodi', 'arias', 'bizarre', 'statement', 'reader', 'warn', 'content', 'graphic', '32', 'year']
# the first amendment doesn't protect the federal workers tweeting out climate data still, there may be other protections available to them.
# ['amendment', 'protect', 'federal', 'worker', 'tweet', 'climate', 'datum', 'protection', 'available']
# in iran and north korea, trump is playing with nuclear fire the stakes are unbearably high.
# ['iran', 'north', 'korea', 'trump', 'play', 'nuclear', 'fire', 'stake', 'unbearably', 'high']
# huffpost rise: what you need to know on june 13 welcome to the huffpost rise morning newsbrief, a short wrap-up of the news to help you start your day.
# ['huffpost', 'rise', 'need', 'know', 'june', '13', 'welcome', 'huffpost', 'rise', 'morning', 'newsbrief', 'short', 'wrap', 'news', 'help', 'start', 'day']
# john mccain: it's 'sad' how obama is full of 'self-pity'
# ['john', 'mccain', 'sad', 'obama', 'self', 'pity']
# the republican assault on the integrity of the supreme court since 1973, i have been a professor of constitutional law. the supreme court is at the very center of my professional life
# ...
# two faces of andrew cuomo: not the answer for democrats i can’t tell if the democrats are drooling in anticipation at the prospects of defeating an enfeebled donald trump infested
# ['face', 'andrew', 'cuomo', 'answer', 'democrats', 'tell', 'democrats', 'drool', 'anticipation', 'prospect', 'defeat', 'enfeeble', 'donald', 'trump', 'infest']
# i'm a republican, but this isn't the tax reform our country needs the tax plan currently being considered by republican leadership is a broken promise.
# ['republican', 'tax', 'reform', 'country', 'need', 'tax', 'plan', 'currently', 'consider', 'republican', 'leadership', 'broken', 'promise']
# an abominable massacre of poor children's futures the united states congress and trump administration are engaged in a morally abominable massacre of the hopes, dreams and
# ['abominable', 'massacre', 'poor', 'child', 'future', 'united', 'states', 'congress', 'trump', 'administration', 'engage', 'morally', 'abominable', 'massacre', 'hope', 'dream']
# new devos loan forgiveness plan: another assault on students and gift to predatory schools it took betsy devos nearly a year to take any action on the nearly 100,000 applications by former students who assert that
# ['new', 'devos', 'loan', 'forgiveness', 'plan', 'assault', 'student', 'gift', 'predatory', 'school', 'betsy', 'devos', 'nearly', 'year', 'action', 'nearly', '100,000', 'application', 'student', 'assert']
# virginia republican channels donald trump in new campaign tone a populist primary opponent put pressure on ed gillespie to shift further right.
# ['virginia', 'republican', 'channel', 'donald', 'trump', 'new', 'campaign', 'tone', 'populist', 'primary', 'opponent', 'pressure', 'ed', 'gillespie', 'shift', 'far', 'right']
# dallas killer wrote cryptic messages in his own blood at site of standoff, police say he left the letters "rb" in the building where police killed him.
# ['dallas', 'killer', 'write', 'cryptic', 'message', 'blood', 'site', 'standoff', 'police', 'leave', 'letter', 'rb', 'building', 'police', 'kill']
# domestic terrorists organizing online are 'real threat,' doj warns "more people have died in this country in attacks by domestic extremists than in attacks associated with international terrorist groups."
# ['domestic', 'terrorist', 'organize', 'online', 'real', 'threat', 'doj', 'warn', 'people', 'die', 'country', 'attack', 'domestic', 'extremist', 'attack', 'associate', 'international', 'terrorist', 'group']
# college ready baloney in fact, we have no clear, complete, scientifically supported picture of what a college ready student looks like, nor any proven way to measure the complex of qualities (that we still can't name and quantify). standardized test scores are not a proxy, not even a bad one
# ['college', 'ready', 'baloney', 'fact', 'clear', 'complete', 'scientifically', 'support', 'picture', 'college', 'ready', 'student', 'look', 'like', 'prove', 'way', 'measure', 'complex', 'quality', 'quantify', 'standardized', 'test', 'score', 'proxy', 'bad']
# domestic murder and murder-suicide: it's not about the relationship by relying solely on non-experts as sources of information, the media wittingly or unwittingly reinforces misconceptions about domestic homicides. domestic homicides sometimes provide experts with the opportunity to call attention to the underlying realities -- but only when the media thinks to call us.
# ['domestic', 'murder', 'murder', 'suicide', 'relationship', 'rely', 'solely', 'non', 'expert', 'source', 'information', 'medium', 'wittingly', 'unwittingly', 'reinforce', 'misconception', 'domestic', 'homicide', 'domestic', 'homicide', 'provide', 'expert', 'opportunity', 'attention', 'underlie', 'reality', '--', 'media', 'think']
# hillary clinton promises deportation relief, despite supreme court ruling she also went after donald trump for his anti-latino comments.
# ['hillary', 'clinton', 'promise', 'deportation', 'relief', 'despite', 'supreme', 'court', 'ruling', 'donald', 'trump', 'anti', 'latino', 'comment']
# net neutrality is a class issue it would unfairly discriminate against poorer communities who can’t necessarily pay more for faster internet access.
# ['net', 'neutrality', 'class', 'issue', 'unfairly', 'discriminate', 'poor', 'community', 'necessarily', 'pay', 'fast', 'internet', 'access']
# republicans fail on health care. here's why the rest of trump's agenda won't be 'so easy,' either they're waging a legislative battle on two fronts with no compromise in sight.
# ['republicans', 'fail', 'health', 'care', 'rest', 'trump', 'agenda', 'easy', 'wage', 'legislative', 'battle', 'compromise', 'sight']
# a new aumf: what is the obama administration afraid of? either the president needs some new faces in the office of legal counsel, or his team needs to do what many of his allies on capitol hill are calling for: ask congress to grant new statutory authority for the military campaign against isil in both iraq and syria. what is the administration afraid of?
# ['new', 'aumf', 'obama', 'administration', 'afraid', 'president', 'need', 'new', 'face', 'office', 'legal', 'counsel', 'team', 'need', 'ally', 'capitol', 'hill', 'ask', 'congress', 'grant', 'new', 'statutory', 'authority', 'military', 'campaign', 'isil', 'iraq', 'syria', 'administration', 'afraid']
# can congress start the year with a commitment to bipartisanship? as we begin the new congress, america sees the two parties in both the house and the senate, along with the white house, making statements that establish positions that distinguish one from another.
# ['congress', 'start', 'year', 'commitment', 'bipartisanship', 'begin', 'new', 'congress', 'america', 'party', 'house', 'senate', 'white', 'house', 'statement', 'establish', 'position', 'distinguish']
# videocracy - filmed violence that galvanizes opinion and policy (see isis and women) katrina and lowry debate whether a) beheadings and media war whoops forced obama's hand; b) he gets a boost or blame in november; c) he'll escalate if bombs-without-boots fails. what now happens to his desired pivot to asia, climate, inequality? ray rice too is tackled by tape. is a video worth a million words?
# ['videocracy', 'film', 'violence', 'galvanize', 'opinion', 'policy', 'isis', 'woman', 'katrina', 'lowry', 'debate', 'beheading', 'medium', 'war', 'whoop', 'force', 'obama', 'hand', 'b', 'boost', 'blame', 'november', 'c', 'escalate', 'bomb', 'boot', 'fail', 'happen', 'desire', 'pivot', 'asia', 'climate', 'inequality', 'ray', 'rice', 'tackle', 'tape', 'video', 'worth', 'million', 'word']
# eric cantor's complicated relationship with immigration reform
# ['eric', 'cantor', 'complicated', 'relationship', 'immigration', 'reform']
# football players charged with attempted rape of special-education student
# ['football', 'player', 'charge', 'attempt', 'rape', 'special', 'education', 'student']
# street artist gives johannesburg's decrepit landmarks a neon pink makeover
# ['street', 'artist', 'johannesburg', 'decrepit', 'landmark', 'neon', 'pink', 'makeover']
# suspect reportedly arrested over explosives sent to washington, d.c. area the fbi was expected to disclose the arrest on tuesday, a source said.
# ['suspect', 'reportedly', 'arrest', 'explosive', 'send', 'washington', 'd.c', 'area', 'fbi', 'expect', 'disclose', 'arrest', 'tuesday', 'source']
# where is president trump's high-performance team? president trump ran on his business experience and ability to get things done. so why are so many important positions in his government still vacant?
# ['president', 'trump', 'high', 'performance', 'team', 'president', 'trump', 'run', 'business', 'experience', 'ability', 'thing', 'important', 'position', 'government', 'vacant']
# yes, bookmobiles are still a thing. (we checked.) the number of bookmobiles in the united states has fallen since 1995, from nearly 1,000 to fewer than 650. but in rural areas, librarians say their services remain vital.
# ['yes', 'bookmobile', 'thing', 'check', 'number', 'bookmobile', 'united', 'states', 'fall', '1995', 'nearly', '1,000', '650', 'rural', 'area', 'librarian', 'service', 'remain', 'vital']
# north carolina gun group raffles ar-15 rifle with a picture of hillary clinton entrance money will be used in campaigns against democratic candidates.
# ['north', 'carolina', 'gun', 'group', 'raffle', 'ar-15', 'rifle', 'picture', 'hillary', 'clinton', 'entrance', 'money', 'use', 'campaign', 'democratic', 'candidate']
# fcc approves a new 3-digit suicide hotline when the rule is finalized, people struggling with suicidal thoughts will be able to get help by dialing 988.
# ['fcc', 'approve', 'new', '3', 'digit', 'suicide', 'hotline', 'rule', 'finalize', 'people', 'struggle', 'suicidal', 'thought', 'able', 'help', 'dial', '988']
# watch how excited shep smith gets about chapstick we're with you, shep.
# ['watch', 'excited', 'shep', 'smith', 'chapstick', 'shep']
# justice department says it's not trying to be a buzzkill on legal weed ― yet despite ominous comments from trump administration officials, the doj says it's not shifting policy right now.
# ['justice', 'department', 'try', 'buzzkill', 'legal', 'weed', '―', 'despite', 'ominous', 'comment', 'trump', 'administration', 'official', 'doj', 'shift', 'policy', 'right']
# republicans explain why they want permanent tax cuts for corporations but not people corporations are people, my friends!
# ['republicans', 'explain', 'want', 'permanent', 'tax', 'cut', 'corporation', 'people', 'corporation', 'people', 'friend']
# trump delivered a dire, frightening speech, dems say even some republicans were nonplussed by a brief address that bashed lawmakers.
# ['trump', 'deliver', 'dire', 'frightening', 'speech', 'dem', 'republicans', 'nonplus', 'brief', 'address', 'bash', 'lawmaker']
# mr. trump, 17 presidents before you protected our national parks. will you? the focus on reducing our public lands sent me looking to see what former presidents have done.
# ['mr', 'trump', '17', 'president', 'protect', 'national', 'park', 'focus', 'reduce', 'public', 'land', 'send', 'look', 'president']
# remains of minnesota boy missing since 1989 found his parents became tireless advocates for missing children after his disappearance.
# ['remain', 'minnesota', 'boy', 'miss', '1989', 'find', 'parent', 'tireless', 'advocate', 'miss', 'child', 'disappearance']
# joe biden expresses support for cease-fire in call with israeli prime minister netanyahu a majority of democrats in the senate recently urged the president to call for a cease-fire between israel and hamas.
# ['joe', 'biden', 'express', 'support', 'cease', 'fire', 'israeli', 'prime', 'minister', 'netanyahu', 'majority', 'democrats', 'senate', 'recently', 'urge', 'president', 'cease', 'fire', 'israel', 'hamas']
# trump is scrambling to avoid a special election defeat in this rust belt district democrat conor lamb is hoping for victory in a union-heavy district that trump won by 20 points.
# ['trump', 'scramble', 'avoid', 'special', 'election', 'defeat', 'rust', 'belt', 'district', 'democrat', 'conor', 'lamb', 'hope', 'victory', 'union', 'heavy', 'district', 'trump', 'win', '20', 'point']
# steve bannon removed from the national security council despite his white nationalist ties and support for islamophobic policies, bannon remains hugely influential.
# ['steve', 'bannon', 'remove', 'national', 'security', 'council', 'despite', 'white', 'nationalist', 'tie', 'support', 'islamophobic', 'policy', 'bannon', 'remain', 'hugely', 'influential']
# new law makes period products free for all in scotland the period products act says that schools, universities and government buildings must make tampons and pads available for free in bathrooms.
# ['new', 'law', 'period', 'product', 'free', 'scotland', 'period', 'product', 'act', 'school', 'university', 'government', 'building', 'tampon', 'pad', 'available', 'free', 'bathroom']
# state department protest of donald trump’s immigration ban hits nearly 900 names the white house suggested dissenters who can’t support the new president should find new work.
# ['state', 'department', 'protest', 'donald', 'trump', 'immigration', 'ban', 'hit', 'nearly', '900', 'white', 'house', 'suggest', 'dissenter', 'support', 'new', 'president', 'find', 'new', 'work']
# haunting halloween nightmares for left and right hillary clinton turns out to be the one who refuses to concede on the night of the election, and demands recounts everywhere. even after the recounts, however, it becomes apparent that she lost and donald j. trump will be our next president.
# ['haunt', 'halloween', 'nightmare', 'left', 'right', 'hillary', 'clinton', 'turn', 'refuse', 'concede', 'night', 'election', 'demand', 'recount', 'recount', 'apparent', 'lose', 'donald', 'j.', 'trump', 'president']
# immigrant children accuse border patrol of abuse and neglect, report shows one 16-year-old filed a complaint alleging that a border patrol agent "threw him down and smashed his head into the ground with his boot."
# ['immigrant', 'child', 'accuse', 'border', 'patrol', 'abuse', 'neglect', 'report', '16', 'year', 'old', 'file', 'complaint', 'allege', 'border', 'patrol', 'agent', 'throw', 'smash', 'head', 'ground', 'boot']
# chief justice roberts made 'human error' in overlooking conflict of interest the head of the supreme court inadvertently participated in a case involving a company where he had a significant financial stake.
# ['chief', 'justice', 'roberts', 'human', 'error', 'overlook', 'conflict', 'interest', 'head', 'supreme', 'court', 'inadvertently', 'participate', 'case', 'involve', 'company', 'significant', 'financial', 'stake']
# after outcry, arizona gop kills bill that would've treated protesters like terrorists "people need to know we are not about limiting people’s rights,” arizona house speaker j.d. mesnard said.
# ['outcry', 'arizona', 'gop', 'kill', 'bill', 'treat', 'protester', 'like', 'terrorist', 'people', 'need', 'know', 'limit', 'people', 'right', 'arizona', 'house', 'speaker', 'j.d', 'mesnard']
# scott walker says there are a 'handful of reasonable, moderate followers of islam' there are more than a handful.
# ['scott', 'walker', 'handful', 'reasonable', 'moderate', 'follower', 'islam', 'handful']
# #utadna grad student of the year
# ['utadna', 'grad', 'student', 'year']
# the tyranny of the nanny state, where the government knows what's best for you having allowed the government to expand and exceed our reach, we find ourselves on the losing end of a tug-of-war over control of our country and our lives.
# ['tyranny', 'nanny', 'state', 'government', 'know', 'good', 'having', 'allow', 'government', 'expand', 'exceed', 'reach', 'find', 'lose', 'end', 'tug', 'war', 'control', 'country', 'life']
# joe scarborough: trump's legal strategy is like 'a monkey throwing poo against the wall' "it doesn't usually turn out well," the msnbc host said of feces flinging.
# ['joe', 'scarborough', 'trump', 'legal', 'strategy', 'like', 'monkey', 'throw', 'poo', 'wall', 'usually', 'turn', 'msnbc', 'host', 'fece', 'flinging']
# utah woman sentenced to 30 years for killing baby with methadone courtney howell sad she spiked her girl's bottle with the drug to help her sleep.
# ['utah', 'woman', 'sentence', '30', 'year', 'kill', 'baby', 'methadone', 'courtney', 'howell', 'sad', 'spike', 'girl', 'bottle', 'drug', 'help', 'sleep']
# the white house keeps lying about donald trump's taxes for the last time, the president can release his tax returns even if he's under audit.
# ['white', 'house', 'lie', 'donald', 'trump', 'taxis', 'time', 'president', 'release', 'tax', 'return', 'audit']
# brazil's president michel temer charged with corruption the country's top prosecutor has charged the president with accepting bribes.
# ['brazil', 'president', 'michel', 'temer', 'charge', 'corruption', 'country', 'prosecutor', 'charge', 'president', 'accept', 'bribe']
# what the census tells us about american politics growing diversity and urban populations should benefit democrats — but the senate's rural bias is getting worse.
# ['census', 'tell', 'american', 'politic', 'grow', 'diversity', 'urban', 'population', 'benefit', 'democrat', '—', 'senate', 'rural', 'bias', 'bad']

# %%
# Accuracy
print("Train Accuracy: ", model_pipe_NB.score(x_train.values.astype('U'), y_train))

# Accuracy
print("Test Accuracy: ", model_pipe_NB.score(x_test.values.astype('U'), y_test))
# Out:
# Train Accuracy:  0.8349166462368227
# Test Accuracy:  0.8226280951213533

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier_NB = RandomForestClassifier()

# %%
from sklearn.pipeline import Pipeline

# %%
# Create the  pipeline to clean, tokenize, vectorize, and classify using"Count Vectorizor"
# Multiple models can be added to the Pipeline object to be executed in sequence.
model_pipe_NB = Pipeline( [ ('vectorizer', tfvectorizer),
                         ('classifier', classifier_NB) ] )

# %%
model_pipe_NB.fit(x_train.values.astype('U'),y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('vectorizer',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 1), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_patt...
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=None, max_features='auto',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %% [markdown]
# **PREDICT VALUES**

# %%
preds_RF = model_pipe_NB.predict(x_test.values)

# %%
print("Train Accuracy: ", model_pipe_NB.score(x_train.values.astype('U'), y_train))

# Accuracy
print("Test Accuracy: ", model_pipe_NB.score(x_test.values.astype('U'), y_test))

# %% [markdown]
# **CONFUSION MATRIX**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
conf_matrix = confusion_matrix(y_test,preds_RF)

# %%
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')

plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
output = pd.DataFrame({'Id': x_test.index,
                       'Category': preds_RF})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# **UNDERSAMPLING**

# %%
# class count
politics_count, crime_count,world_news_count,arts_count,education_count = df['category'].value_counts()


# Separate class
arts =df[df['category'] =='ARTS']
crime =df[df['category'] =='CRIME']
education= df[df['category'] =='EDUCATION']
politics = df[df['category'] =='POLITICS']
world_news = df[df['category']=='WORLD NEWS']# print the shape of the class
print('class arts:', arts.shape)
print('class crime:', crime.shape)
print('class education:', education.shape)
print('class politics:', politics.shape)
print('class world_news:', world_news.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-2d3bfe60f5a7> in <module>()
#       1 # class count
# ----> 2 politics_count, crime_count,world_news_count,arts_count,education_count = df['category'].value_counts()
#       3
#       4
#       5 # Separate class
#
# ValueError: too many values to unpack (expected 5)

# %%
arts.head(2)
# Out:
#       category                                               text
# 36407     ARTS        10 Budget-Friendly Street Photography Books
# 33819     ARTS  The Composers Speak: Broadway Composers Partic...

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
from matplotlib import pyplot
from sklearn.preprocessing import LabelEncoder

# %%
X = df['text']
y = df['category']
# label encode the target variable
y = LabelEncoder().fit_transform(y)
# transform the dataset
strategy = {0:100, 1:100, 2:200, 3:200, 4:200, 5:200}
oversample = SMOTE(sampling_strategy=strategy)
X, y = oversample.fit_resample(X.value_counts(), y)
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
pyplot.bar(counter.keys(), counter.values())
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-db878ad28cab> in <module>()
#       6 strategy = {0:100, 1:100, 2:200, 3:200, 4:200, 5:200}
#       7 oversample = SMOTE(sampling_strategy=strategy)
# ----> 8 X, y = oversample.fit_resample(X.value_counts(), y)
#       9 # summarize distribution
#      10 counter = Counter(y)
#
# /usr/local/lib/python3.7/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      78         self._deprecate_ratio()
#      79
# ---> 80         X, y, binarize_y = self._check_X_y(X, y)
#      81
#      82         self.sampling_strategy_ = check_sampling_strategy(
#
# /usr/local/lib/python3.7/dist-packages/imblearn/base.py in _check_X_y(X, y)
#     136     def _check_X_y(X, y):
#     137         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 138         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc'])
#     139         return X, y, binarize_y
#     140
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     554                     "Reshape your data either using array.reshape(-1, 1) if "
#     555                     "your data has a single feature or array.reshape(1, -1) "
# --> 556                     "if it contains a single sample.".format(array))
#     557
#     558         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[90  3  2 ...  1  1  1].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# **undersampling politics category**

# %%
import pandas as pd
path  = '/content/drive/MyDrive/Colab Notebooks/news40k.csv'
df = pd.read_csv(path)

# %%
import numpy as np

politics_under = np.random.choice(arts_count,politics_count, replace=True)

mf =  pd.dataframe([arts, crime,education,politics_under,world_news])
#convert array to dataframe and perform it on whole data 40k file
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-fdbe83353f2d> in <module>()
#       3 politics_under = np.random.choice(arts_count,politics_count, replace=True)
#       4
# ----> 5 mf =  pd.concat([arts, crime,education,politics_under,world_news])
#       6 #convert array to dataframe and perform it on whole data 40k file
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# --> 284         sort=sort,
#     285     )
#     286
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     357                     "only Series and DataFrame objs are valid"
#     358                 )
# --> 359                 raise TypeError(msg)
#     360
#     361             # consolidate
#
# TypeError: cannot concatenate object of type '<class 'numpy.ndarray'>'; only Series and DataFrame objs are valid

# %%
mf.head(5)
# Out:
#                                                    0
# 0        category                                ...
# 1        category                                ...
# 2          category                              ...
# 3  [541, 727, 978, 844, 1152, 958, 693, 597, 740,...
# 4          category                              ...

# %%
import nltk
import spacy
from spacy import displacy
from  spacy.lang.en.stop_words import STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer
import en_core_web_sm
import string
import nltk
nltk.download('stopwords');
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#converting text to lowercase
df['text'] = df['text'].str.lower()

# %%
from nltk.corpus import stopwords
stop_words = list(stopwords.words('english'))
nlp = spacy.load('en_core_web_sm')
#converting to tokens

def identify_tokens(row):
    text = nlp(row)
    # taken only words (not punctuation)
    token_words = [w for w in text if w.isalpha()]
    # taken only words (not stopwords)
    token_words = [w for w in text if w not in stop_words]
    return token_words


df['text'] = df.apply(identify_tokens, axis=1)

# %% [markdown]
# **delete lower cell**

# %%
# Spliting dataframe into x and y
y = df['category']
X = df['text']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['category'], train_size=0.2, shuffle=True, random_state=1)

# %%
 # Fit a tokenizer
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X_train)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#tfvectorizer = TfidfVectorizer(tokenizer = identify_tokens)

# %%
from sklearn.pipeline import Pipeline

# %%
#splitting model
X_train, X_test, y_train, y_test = train_test_split( df['text'], df['category'],
                                                    test_size = 0.2, random_state = 678)
from sklearn.naive_bayes import MultinomialNB
classifier_NB = MultinomialNB()

# %%
model_pipe_NB = Pipeline( [ ('vectorizer', tfvectorizer),
                         ('classifier', classifier_NB) ] )

# %%
model_pipe_NB.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-2a9ea4dd4e9d> in <module>()
# ----> 1 model_pipe_NB.fit(X_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     348             This estimator
#     349         """
# --> 350         Xt, fit_params = self._fit(X, y, **fit_params)
#     351         with _print_elapsed_time('Pipeline',
#     352                                  self._log_message(len(self.steps) - 1)):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     313                 message_clsname='Pipeline',
#     314                 message=self._log_message(step_idx),
# --> 315                 **fit_params_steps[name])
#     316             # Replace the transformer of the step with the fitted
#     317             # transformer. This is necessary when loading the transformer
#
# /usr/local/lib/python3.7/dist-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     726     with _print_elapsed_time(message_clsname, message):
#     727         if hasattr(transformer, 'fit_transform'):
# --> 728             res = transformer.fit_transform(X, y, **fit_params)
#     729         else:
#     730             res = transformer.fit(X, y, **fit_params).transform(X)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1857         """
#    1858         self._check_params()
# -> 1859         X = super().fit_transform(raw_documents)
#    1860         self._tfidf.fit(X)
#    1861         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1218
#    1219         vocabulary, X = self._count_vocab(raw_documents,
# -> 1220                                           self.fixed_vocabulary_)
#    1221
#    1222         if self.binary:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1129         for doc in raw_documents:
#    1130             feature_counter = {}
# -> 1131             for feature in analyze(doc):
#    1132                 try:
#    1133                     feature_idx = vocabulary[feature]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     103             doc = preprocessor(doc)
#     104         if tokenizer is not None:
# --> 105             doc = tokenizer(doc)
#     106         if ngrams is not None:
#     107             if stop_words is not None:
#
# <ipython-input-80-ee779fb5bc26> in identify_tokens(sentence)
#      24     # Rule 2
#      25     # Remove stop words and punctuation
# ---> 26     tokens = [ token for token in tokens if token not in stopwords and token not in punctuations ]
#      27
#      28     return tokens
#
# <ipython-input-80-ee779fb5bc26> in <listcomp>(.0)
#      24     # Rule 2
#      25     # Remove stop words and punctuation
# ---> 26     tokens = [ token for token in tokens if token not in stopwords and token not in punctuations ]
#      27
#      28     return tokens
#
# TypeError: argument of type 'WordListCorpusReader' is not iterable

# %%
'''import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
for sentence in df["text"]:
  doc = nlp(sentence)
  print([(X.text, X.label_) for X in doc.ents])
'''
# Out:
# [('house', 'ORG')]
# [('three years', 'DATE')]
# []
# [('etgar keret examines life', 'PERSON'), ('israel', 'GPE')]
# []
# [('a day', 'DATE')]
# [('massart', 'ORG'), ('boston', 'GPE')]
# [('hungarian', 'NORP')]
# []
# [('trisha williams', 'PERSON')]
# [("new york's", 'GPE')]
# []
# [('2.0', 'CARDINAL')]
# []
# []
# [('london', 'GPE')]
# []
# []
# [('gloria', 'PERSON')]
# [('world', 'ORG')]
# [("anish kapoor's", 'PERSON')]
# []
# []
# [('this summer', 'DATE')]
# []
# [('art basel', 'PERSON'), ('basel 2015', 'DATE')]
# [("yoko ono's", 'PERSON')]
# [('max ginsburg', 'PERSON')]
# [('5', 'CARDINAL'), ('2015', 'DATE')]
# [("yiddish-wong-ish --it's", 'GPE')]
# [("b'way", 'CARDINAL'), ('35', 'CARDINAL')]
# []
# [("the royal shakespeare company's", 'ORG'), ('venice', 'GPE')]
# []
# [('today', 'DATE')]
# [('bosque', 'GPE')]
# []
# []
# []
# [('america', 'GPE')]
# [('summer', 'DATE'), ('bingo', 'PERSON'), ('summer', 'DATE')]
# [('david ligare', 'PERSON'), ('the crocker art museum', 'ORG'), ('sacramento', 'GPE')]
# []
# []
# []
# []
# []
# [('san francisco', 'GPE')]
# [('the fourth of july', 'DATE')]
# [('ruth appelhof', 'PERSON')]
# [('13', 'CARDINAL'), ('american', 'NORP')]
# [('15', 'CARDINAL'), ('this summer', 'DATE')]
# [('a starry night', 'TIME'), ('philadelphians', 'NORP')]
# []
# [("lucinda bunnen's", 'ORG')]
# []
# [('5', 'CARDINAL'), ('20', 'CARDINAL')]
# [("deborah levy's", 'PERSON')]
# [("leonardo da vinci's", 'PERSON')]
# [('mark twain', 'PERSON')]
# [('sophie calle', 'PERSON')]
# [('7', 'CARDINAL')]
# []
# [('frida', 'GPE'), ('frida', 'GPE')]
# []
# [('ira world premiere', 'ORG')]
# []
# [('doc', 'ORG')]
# [('gustavo', 'ORG'), ('9 beethoven', 'CARDINAL'), ('first', 'ORDINAL')]
# [('keatley', 'ORG')]
# [('melanie daniel', 'PERSON'), ('venice', 'GPE')]
# [('15', 'CARDINAL'), ('chernobyl', 'GPE')]
# [('donald rosenfeld', 'PERSON')]
# [('american', 'NORP'), ('i.m.', 'GPE')]
# [('korean american', 'NORP'), ('nam june', 'PERSON')]
# []
# []
# [('european', 'NORP')]
# [('jim mckinniss captures', 'PERSON')]
# [('morocco', 'GPE')]
# [('new york city', 'GPE'), ("american ballet theatre's", 'ORG')]
# []
# [('one', 'CARDINAL')]
# [('summer', 'DATE'), ('europe', 'LOC')]
# [("jonathan monaghan's", 'PERSON'), ('3d', 'PRODUCT')]
# [('10', 'CARDINAL')]
# []
# [('india', 'GPE')]
# []
# []
# [('jean ritchie', 'PERSON'), ('the cool of the day', 'DATE')]
# [('asian pacific american', 'ORG'), ('united', 'ORG'), ('asian american', 'ORG'), ('pacific islander', 'ORG')]
# [('cedar lake contemporary', 'FAC')]
# [('morrow', 'DATE'), ('kimball', 'GPE')]
# [('forever bleeker street', 'ORG')]
# [('one year', 'DATE')]
# []
# [("zombie joe's", 'PERSON')]
# [("rajiv joseph's", 'PERSON')]
# [('10', 'CARDINAL')]
# [('marijuana', 'GPE')]
# [('jeanne dunn', 'PERSON')]
# [('25', 'CARDINAL')]
# [('artist susan sweet', 'PERSON'), ('nova', 'LOC')]
# [('10', 'CARDINAL')]
# []
# []
# [('bert berns', 'PERSON')]
# []
# []
# [('15', 'CARDINAL'), ('instagram', 'NORP')]
# [('russia', 'GPE')]
# [('english', 'NORP')]
# []
# [('susan lizotte', 'PERSON'), ('blood &', 'ORG')]
# [('peruvian', 'NORP'), ('bury', 'ORG')]
# [('sarah kaufman', 'PERSON')]
# [('broadway musical', 'FAC')]
# [('2015', 'DATE')]
# []
# []
# [('year', 'DATE')]
# [('brooklyn', 'GPE')]
# [("new york's", 'GPE')]
# [('the bata shoe museum', 'ORG'), ('toronto', 'GPE'), ('20th', 'ORDINAL')]
# []
# []
# [('54', 'CARDINAL')]
# [('ballet zaida debuts', 'PERSON'), ('creator oliver', 'PERSON')]
# []
# [('francis picabia', 'GPE'), ('the kunsthaus zurich', 'FAC')]
# [('jeff koons', 'PERSON')]
# []
# [('summer', 'DATE')]
# [('this summer', 'DATE')]
# [('peter beard', 'PERSON')]
# [('street art fair la', 'FAC')]
# [('sue paterson', 'PERSON'), ('hollywood', 'GPE')]
# [('99%', 'PERCENT')]
# [('van gogh', 'PERSON')]
# []
# []
# []
# []
# []
# []
# []
# [('2016', 'DATE')]
# []
# [('joe morton', 'PERSON'), ('dick gregory', 'PERSON'), ('shakespeare', 'PERSON'), ('1599', 'DATE')]
# [('south africa', 'GPE')]
# []
# []
# [('9', 'CARDINAL')]
# [('8', 'CARDINAL'), ('macon', 'GPE'), ('georgia', 'GPE')]
# [('rossini', 'PERSON')]
# [("john hollenbeck's", 'PERSON')]
# []
# [('thirty-five', 'CARDINAL')]
# []
# [('donna quesada', 'PERSON')]
# [('5', 'CARDINAL'), ('winter', 'DATE'), ('new york', 'GPE')]
# []
# []
# [('finian', 'NORP')]
# [('von', 'PERSON')]
# [('thomas bayrle', 'PERSON'), ('lenbachhaus münchen', 'PERSON'), ('kunstbau', 'PERSON')]
# [('bernard taper', 'PERSON')]
# [('first', 'ORDINAL')]
# [('art basel', 'PERSON'), ('miami beach', 'GPE'), ('2016', 'CARDINAL'), ('the week', 'DATE')]
# []
# [('dallas', 'GPE'), ('french', 'NORP'), ("sur l'herbe", 'PERSON'), ('monet', 'PERSON')]
# [('jan fabre', 'PERSON'), ('2', 'CARDINAL')]
# [('hamilton brouhaha', 'PERSON')]
# []
# [('kenneth branagh', 'PERSON'), ("john osborne's", 'PERSON'), ('the entertainer', 'WORK_OF_ART'), ('kemp', 'PERSON'), ('one night', 'TIME'), ('miami', 'GPE'), ("peter shaffer's", 'PERSON'), ('"how to hide a lion" for kids', 'WORK_OF_ART')]
# [('russia', 'GPE'), ('paris', 'GPE')]
# [('third', 'ORDINAL')]
# [('umbrellas', 'GPE'), ('magritte', 'PERSON')]
# [('jerry bergonzi', 'PERSON')]
# [('summer', 'DATE')]
# [('savannah college', 'ORG')]
# [('montreal', 'GPE'), ('virée classique', 'ORG')]
# [("james chuda's", 'PERSON')]
# [('chaka khan', 'PERSON'), ('atlanta', 'GPE')]
# [('richard ford &', 'PERSON')]
# [('jim bachor', 'PERSON'), ('chicago', 'GPE')]
# [('ann', 'PERSON')]
# [('elizabeth murray', 'PERSON'), ('kristi zea', 'PERSON')]
# []
# []
# []
# [('23', 'CARDINAL')]
# [('margaret bowland', 'PERSON')]
# []
# [("andrew lloyd webber's", 'PERSON')]
# [('2015', 'DATE')]
# [('arianne levene', 'PERSON')]
# [("john yearley's", 'PERSON'), ('the unrepeatable moment', 'WORK_OF_ART')]
# []
# [('hell', 'ORG')]
# [('george lucas', 'PERSON'), ('samuel l. jackson', 'PERSON'), ('angela lansbury', 'ORG'), ('james earl jones', 'PERSON')]
# [('9', 'CARDINAL')]
# []
# [('barbecue', 'GPE')]
# [('california', 'GPE')]
# [('98th', 'ORDINAL')]
# [('stingy stein', 'PERSON')]
# []
# []
# [("l.a.'s", 'GPE')]
# [('la', 'PERSON')]
# []
# [('100 years', 'DATE')]
# []
# []
# []
# [('three', 'CARDINAL')]
# []
# []
# [("william kentridge's", 'PERSON'), ('rome', 'GPE')]
# [('asian', 'NORP')]
# [('11th-century', 'DATE'), ('scotland', 'GPE')]
# [('adrian', 'NORP'), ('robert', 'PERSON'), ("stephen sondheim's", 'PERSON')]
# [('billy eichner', 'PERSON'), ('2nd', 'ORDINAL'), ('variety sketch series', 'WORK_OF_ART'), ('emmy award', 'WORK_OF_ART')]
# []
# [('new york', 'GPE')]
# []
# []
# [('larry young', 'PERSON'), ('paris', 'GPE')]
# []
# []
# [('korea', 'GPE'), ('jin yong lee', 'PERSON')]
# [('first nighter', 'ORG'), ('ann', 'PERSON')]
# [('jennifer simard', 'PERSON')]
# []
# [("la phil's", 'PERSON')]
# []
# []
# [("constance mallinson's", 'ORG')]
# [('atomos', 'GPE'), ('wayne mcgregor', 'PERSON')]
# [('the new year', 'DATE')]
# []
# [('sally mann', 'PERSON')]
# []
# [('agnes martin', 'PERSON')]
# []
# []
# [("francis upritchard's", 'PERSON')]
# [('american', 'NORP')]
# [('seven', 'CARDINAL')]
# []
# []
# [('broadway', 'FAC')]
# [('anna deavere smith', 'PERSON'), ('44th', 'ORDINAL'), ('jefferson lecture', 'ORG'), ('american', 'NORP')]
# []
# [('80s', 'DATE'), ('vhs', 'ORG')]
# [('peter forgacs', 'PERSON')]
# []
# []
# [('20', 'CARDINAL')]
# [('syzygy', 'PERSON'), ('two', 'CARDINAL')]
# [('ems', 'ORG'), ('1', 'CARDINAL'), ('april 3', 'DATE')]
# [('leo', 'PERSON'), ('instagram', 'NORP'), ('picasso', 'PERSON'), ('electrician', 'PERSON')]
# [('yan', 'ORG'), ('pei ming', 'PERSON')]
# [('photographer david yarrow', 'PERSON'), ('south sudanese', 'NORP'), ('the las vegas strip', 'ORG')]
# []
# [('don carlo', 'PERSON')]
# []
# []
# []
# [('marvin j. taylor', 'PERSON'), ('martha wilson', 'PERSON')]
# [('the british museum in times', 'ORG')]
# []
# [('canadian', 'NORP')]
# []
# [("lisa loeb's", 'PERSON')]
# [('a hundred tons', 'QUANTITY')]
# [('american', 'NORP')]
# []
# [('20', 'CARDINAL'), ('1995', 'DATE')]
# [('2', 'CARDINAL')]
# []
# [('america', 'GPE'), ('today', 'DATE')]
# [('iowa', 'GPE'), ("'39", 'DATE')]
# [('frank moth', 'PERSON')]
# [('american', 'NORP'), ('paris', 'GPE'), ('broadway', 'FAC')]
# []
# [("laura borneman's", 'PERSON')]
# []
# [('bill nighy', 'PERSON'), ('carey mulligan', 'PERSON')]
# [("king henry's", 'PERSON')]
# [("tracey scott wilson's", 'PERSON'), ('clinton', 'PERSON')]
# [('one', 'CARDINAL'), ('the next ice age', 'DATE')]
# [('american', 'NORP')]
# [("wolf hall'", 'PERSON')]
# [('david allan peters', 'PERSON')]
# []
# []
# [("millie brown's", 'PERSON')]
# [('zurich', 'GPE')]
# [('janine molinari', 'PERSON'), ('broadway', 'FAC')]
# [('ran blake', 'PERSON')]
# [('sinatra', 'ORG'), ('centennial year', 'DATE')]
# []
# [('wheelock', 'ORG'), ('rodriguez', 'ORG'), ('godfrey', 'PERSON')]
# []
# [('12', 'CARDINAL')]
# [('basquiat', 'ORG'), ('brooklyn notebooks', 'ORG'), ('kahlo', 'ORG'), ('detroit', 'GPE')]
# [("david rockwell's", 'PERSON'), ('new york', 'GPE')]
# []
# [('paul rand', 'PERSON'), ('the museum of the city of', 'ORG'), ('new york', 'GPE')]
# []
# [('60 years', 'DATE'), ('jane doe', 'PERSON')]
# [('one', 'CARDINAL'), ('berlin', 'GPE')]
# [('china', 'GPE')]
# [('first nighter', 'ORG'), ('three-quarters', 'DATE'), ("the twentieth century'", 'DATE')]
# [('los angeles', 'GPE')]
# []
# [('victoria', 'GPE')]
# [('frida kahlo', 'PERSON'), ('andy warhol', 'PERSON'), ('alexander calder', 'PERSON')]
# [('retro', 'PERSON')]
# [('williams college', 'ORG'), ('andy warhol', 'PERSON')]
# [('hong kong', 'GPE')]
# [('björk', 'ORG'), ('first', 'ORDINAL'), ('vulnicura', 'ORG')]
# [('switzerland', 'GPE'), ('the geffen playhouse', 'FAC')]
# [('envision festival costa rica', 'PRODUCT'), ('2015', 'DATE')]
# [('yangon photo festival', 'FAC')]
# []
# [('5', 'CARDINAL')]
# [('israel', 'GPE')]
# []
# []
# [('tomi ungerer', 'PERSON'), ('a century', 'DATE')]
# [("ron arad's", 'PERSON'), ('paul kasmin gallery', 'PERSON')]
# [('3d', 'CARDINAL')]
# []
# [('retired det', 'PERSON'), ('sonny grosso', 'PERSON'), ('patrick', 'PERSON')]
# []
# [('five years', 'DATE')]
# []
# [('one', 'CARDINAL')]
# [('victoria', 'GPE')]
# [('bernstein', 'ORG')]
# [("burkina faso's", 'PERSON')]
# [('ballet', 'ORG')]
# [('rodchenko', 'PERSON')]
# []
# [('two', 'CARDINAL')]
# [("the middle east's", 'LOC')]
# [('martin short', 'PERSON'), ('matthew broderick', 'PERSON'), ('stockard channing', 'PERSON')]
# [('comedian robert dubac', 'PERSON'), ('one', 'CARDINAL')]
# [('park hyatt', 'FAC')]
# [('night', 'TIME'), ("the guggenheim museum's", 'ORG')]
# [('ryder', 'ORG'), ('red bull studios', 'ORG'), ('new york', 'GPE')]
# []
# [('1854', 'DATE')]
# [('paris', 'GPE')]
# []
# []
# []
# []
# [('scott schwartz', 'PERSON')]
# [('h2o', 'PRODUCT')]
# []
# [('street artist', 'ORG'), ('alice pasquini', 'PERSON')]
# [('lomax', 'GPE')]
# [('today', 'DATE')]
# []
# []
# [('english', 'LANGUAGE')]
# []
# []
# []
# []
# []
# []
# [('one', 'CARDINAL'), ('morocco', 'GPE')]
# [('10', 'CARDINAL')]
# [('america', 'GPE'), ('ag', 'ORG')]
# [('3', 'CARDINAL')]
# [('biesenbach', 'PERSON'), ('fluxus', 'PERSON')]
# [('5', 'CARDINAL'), ('new york', 'GPE')]
# [('atlanta', 'GPE')]
# []
# [('michael pearce', 'PERSON')]
# [('tim allen', 'PERSON')]
# []
# [('romeo', 'ORG'), ('juliet', 'ORG'), ('san francisco', 'GPE')]
# [('three', 'CARDINAL')]
# []
# [('natalie arnoldi', 'PERSON')]
# [('voyeur theatre', 'PERSON'), ('millennial', 'GPE')]
# []
# [('10', 'CARDINAL'), ('the next 10 years', 'DATE')]
# [('confucius', 'ORG')]
# []
# []
# [('andy warhol', 'PERSON')]
# []
# []
# []
# [('40', 'CARDINAL'), ('10', 'CARDINAL')]
# [('instagram', 'NORP')]
# [('grrrl power', 'ORG'), ("'90s", 'DATE')]
# []
# []
# [('ekolu', 'ORG')]
# []
# [('two', 'CARDINAL')]
# []
# []
# []
# [('enwezor', 'ORG'), ('2015', 'DATE'), ('venice', 'GPE')]
# [("apichatpong werasethakul's", 'ORG')]
# []
# [('marina abramovic', 'PERSON'), ("jay z '", 'PERSON')]
# [('romaine brooks', 'PERSON'), ('the 20th century', 'DATE')]
# [('francesca', 'CARDINAL'), ('washington national opera', 'ORG'), ('september 2018', 'DATE')]
# [('f-f-f-fifty', 'PERSON')]
# []
# []
# [('11', 'CARDINAL')]
# []
# [("chris harrison's", 'PERSON')]
# [('bud', 'ORG')]
# []
# [("nikki haskell's", 'ORG')]
# [('101', 'CARDINAL'), ('hiroshima', 'GPE')]
# [('clinton', 'PERSON')]
# [("pascal rioult's", 'GPE')]
# [("cassandra wilson's", 'PERSON'), ('unique holiday', 'PERSON')]
# [('10', 'CARDINAL'), ('this weekend', 'DATE')]
# []
# [('two', 'CARDINAL')]
# [('misty copeland', 'PERSON'), ('75 years', 'DATE'), ('american', 'NORP')]
# [('mark dendy', 'PERSON'), ('joe', 'PERSON')]
# [('stravinsky', 'PERSON')]
# [('san francisco', 'GPE')]
# [('san francisco', 'GPE')]
# []
# []
# []
# []
# []
# [('pulitzer prize', 'WORK_OF_ART')]
# []
# [("rachel rampleman's", 'PERSON')]
# []
# [('haegue yang', 'PERSON'), ('seoul', 'GPE')]
# [('todd williamson', 'PERSON')]
# [('100', 'CARDINAL'), ('west hollwood', 'GPE'), ('april 18', 'DATE')]
# []
# []
# [('zuill bailey', 'PERSON'), ('ernest bloch', 'PERSON')]
# [('american', 'NORP'), ('paris', 'GPE')]
# [("hofesh shechter's", 'PERSON')]
# [('miami art', 'PERSON'), ('miami', 'GPE')]
# []
# [('15', 'CARDINAL')]
# [('edm', 'ORG')]
# [('michael govan', 'PERSON'), ('dave hickey', 'PERSON'), ("michael heizer's", 'PERSON')]
# [("o'casey", 'ORG'), ('irish', 'NORP')]
# [('emily johnson', 'PERSON'), ('new york city', 'GPE')]
# []
# []
# [('year', 'DATE')]
# []
# [('agustin schang', 'PERSON'), ('537', 'CARDINAL')]
# []
# [('7', 'CARDINAL')]
# [('daniel lanois', 'PERSON')]
# [('10', 'CARDINAL')]
# [('one', 'CARDINAL')]
# [('bill graham', 'PERSON')]
# [("trash cuisine scrutinizes man's", 'ORG')]
# [('italy', 'GPE')]
# []
# [('this summer', 'DATE'), ('third', 'ORDINAL')]
# [("ted gioia's", 'PERSON')]
# [('cambodia', 'GPE')]
# []
# [('greg williams', 'PERSON')]
# []
# []
# [('victorian', 'NORP'), ('britain', 'GPE')]
# []
# [('ballet', 'ORG'), ('one', 'CARDINAL')]
# []
# []
# []
# []
# [('anne hathaway', 'PERSON'), ('irish', 'NORP'), ('belfast', 'GPE'), ("red bull theater's", 'ORG')]
# []
# []
# [('tibetan', 'NORP')]
# [('2', 'CARDINAL')]
# [('renée fleming', 'PERSON'), ('broadway', 'FAC')]
# [('ukraine', 'GPE')]
# [('venice', 'GPE')]
# [('texas', 'GPE')]
# [('cribs', 'ORG')]
# [('kayak killer', 'PERSON'), ('up to 4 years', 'DATE'), ('fiancé', 'ORG')]
# []
# [('6', 'CARDINAL')]
# [('us', 'GPE'), ('mexico', 'GPE'), ('three', 'CARDINAL'), ('americans', 'NORP')]
# [('america', 'GPE')]
# [('air force', 'ORG'), ('u.s.', 'GPE')]
# [('filipina model', 'ORG')]
# [('alex wubbels', 'PERSON'), ('utah', 'GPE'), ('500,000', 'MONEY')]
# [('florida', 'GPE')]
# [('3', 'CARDINAL'), ('colorado', 'GPE')]
# [('muslim', 'NORP'), ('new york city', 'GPE')]
# []
# [('2', 'CARDINAL'), ('new york', 'GPE')]
# [('new york', 'GPE')]
# [('meth', 'PERSON'), ('halloween', 'DATE'), ('wisconsin', 'GPE')]
# [('florida', 'GPE'), ('hunt', 'GPE')]
# [('texas', 'GPE')]
# []
# [('at least 26', 'CARDINAL'), ('texas', 'GPE')]
# [('reno', 'GPE'), ('nevada', 'GPE')]
# [('native american', 'NORP'), ('ashland county', 'GPE'), ('mrdjenovich', 'PERSON'), ('justiceforjason', 'PERSON')]
# [('oklahoma', 'GPE')]
# []
# [('tampa', 'GPE')]
# []
# [('air force', 'ORG'), ('dozens', 'CARDINAL')]
# []
# []
# []
# []
# []
# [('ebay', 'ORG'), ('madeleine mccann', 'PERSON')]
# [('baltimore', 'GPE'), ('a day', 'DATE')]
# [('charles manson', 'PERSON')]
# [('sylvester stallone', 'PERSON'), ("the '80s", 'DATE')]
# [('california', 'GPE')]
# [('texas state university', 'ORG')]
# []
# [('hawaii mental hospital', 'ORG')]
# [('ohio', 'GPE')]
# [('mexico', 'GPE'), ('american', 'NORP'), ('3', 'CARDINAL')]
# []
# [('ohio', 'GPE'), ('las vegas', 'GPE')]
# [('newtown shooter', 'PERSON'), ('pedophilia', 'GPE'), ('fbi', 'ORG')]
# [('stephen paddock\xa0', 'PERSON')]
# [('dad', 'PERSON')]
# [('marilou danley', 'PERSON'), ('las vegas', 'GPE')]
# [('stephen paddock', 'PERSON'), ('las vegas', 'GPE')]
# [('charlottesville', 'ORG'), ('organizer jason kessler', 'PERSON')]
# [('american', 'NORP')]
# [('las vegas', 'GPE')]
# [('las vegas', 'GPE')]
# [('stephen paddock', 'PERSON'), ('las vegas', 'GPE')]
# [('las vegas', 'GPE')]
# [('simpson', 'PERSON'), ('nevada', 'GPE')]
# [('las vegas', 'GPE')]
# [('houston', 'GPE')]
# []
# [('decades-old', 'DATE')]
# [('navy', 'ORG')]
# [('oklahoma city', 'GPE')]
# []
# [('st. louis riot police break up', 'ORG')]
# []
# [('2', 'CARDINAL'), ('florida', 'GPE')]
# [('1', 'CARDINAL'), ('3', 'CARDINAL'), ('washington', 'GPE')]
# []
# [('hotel security guard', 'ORG'), ('las vegas', 'GPE')]
# [('las vegas', 'GPE'), ('50 pounds', 'QUANTITY')]
# [('more than 100', 'CARDINAL'), ('puppy', 'GPE')]
# []
# [('california', 'GPE'), ('nevada', 'GPE')]
# []
# []
# [('3', 'CARDINAL')]
# [('joe arpaio', 'PERSON')]
# [('albuquerque', 'ORG')]
# []
# [('florida', 'GPE'), ('mosque', 'GPE')]
# [('alabama', 'ORG'), ('torrey mcnabb', 'PERSON')]
# [('chelsea bomber', 'PERSON'), ('ahmad rahimi', 'PERSON')]
# [('tina frost', 'PERSON'), ('las vegas', 'GPE')]
# [('las vegas', 'GPE')]
# []
# [('google', 'ORG')]
# [('mgm', 'ORG'), ('las vegas', 'GPE')]
# [('utah', 'GPE')]
# [('vegas', 'GPE')]
# [('manhattan', 'GPE')]
# []
# []
# [('florida', 'GPE')]
# [('north carolina', 'GPE'), ('fbi', 'ORG')]
# [("12 years '", 'DATE'), ('florida', 'GPE')]
# [('north carolina', 'GPE')]
# [('vigil', 'ORG'), ('florida', 'GPE')]
# [('florida', 'GPE')]
# []
# [('three', 'CARDINAL'), ('milwaukee county', 'GPE')]
# [('two', 'CARDINAL'), ('ohio', 'GPE'), ('911', 'CARDINAL')]
# [('american', 'NORP')]
# [('second', 'ORDINAL')]
# [('3', 'CARDINAL'), ('larry nassar', 'PERSON')]
# [('nassar', 'ORG'), ('265', 'CARDINAL')]
# [('vegas', 'GPE')]
# [('ex-cop', 'ORG'), ('baltimore', 'GPE')]
# [('4', 'CARDINAL'), ('pennsylvania', 'GPE')]
# []
# [('baltimore', 'GPE')]
# [('larry nassar', 'PERSON')]
# [('u.s.', 'GPE'), ('10', 'CARDINAL'), ('this year', 'DATE')]
# [('cnn', 'ORG')]
# [('more than 9,000', 'CARDINAL')]
# []
# [('dallas hospital', 'ORG')]
# []
# [('sfpd', 'ORG')]
# [('2', 'CARDINAL')]
# [('florida', 'GPE')]
# [('911', 'CARDINAL')]
# [('martin', 'ORG'), ('hillary clinton', 'PERSON')]
# [('alabama school: report', 'ORG')]
# [('indian', 'NORP')]
# [('parkland school', 'ORG'), ('17', 'CARDINAL')]
# []
# [('cuban', 'NORP'), ('7 years', 'DATE')]
# []
# []
# [('parkland high school', 'ORG')]
# [('central michigan university', 'ORG')]
# [("sean hannity's", 'ORG')]
# []
# [("parkland shooter's", 'PERSON')]
# [('north carolina', 'GPE')]
# [('jewish', 'NORP')]
# [('texas', 'GPE'), ('alabama', 'GPE'), ('florida', 'GPE')]
# []
# [('douglas resigns', 'PERSON')]
# [('florida', 'GPE'), ('shooter', 'PERSON')]
# []
# [('13', 'CARDINAL'), ('california', 'GPE')]
# []
# [('2', 'CARDINAL'), ('california', 'GPE')]
# [('veterinarian', 'ORG')]
# []
# [('canadian', 'NORP'), ('toronto', 'GPE')]
# [('canada', 'GPE'), ('13th', 'DATE'), ('2007', 'DATE')]
# []
# [('u.s.', 'GPE')]
# [('arizona', 'GPE')]
# [('dulles airport', 'FAC')]
# []
# [('25 years', 'DATE')]
# []
# [('new york', 'GPE')]
# [('landlord', 'ORG')]
# [('brendan dassey', 'PERSON')]
# []
# [('decades-old', 'DATE')]
# [('new york', 'GPE')]
# [('50', 'CARDINAL'), ('california', 'GPE')]
# []
# [('california', 'GPE')]
# [('michigan', 'GPE')]
# [('california', 'GPE')]
# []
# []
# []
# [('13', 'CARDINAL')]
# [('texas', 'GPE')]
# [('californian', 'NORP')]
# [('nanny $121,000', 'MONEY'), ('2 years', 'DATE')]
# [('vegas mass shooter', 'ORG'), ('hotel', 'ORG')]
# [('white supremacist', 'ORG')]
# [('fbi', 'ORG'), ('clinton', 'ORG')]
# [('colorado', 'GPE')]
# [('less than 1 ounce', 'QUANTITY'), ('marijuana', 'GPE'), ('more than 60', 'CARDINAL'), ('georgia', 'GPE')]
# [('texas', 'GPE')]
# [("new year's eve", 'EVENT')]
# [('2018', 'DATE')]
# [('nigerian', 'NORP'), ('louisiana', 'GPE')]
# [('fbi', 'ORG'), ("david clarke's", 'PERSON')]
# [('2', 'CARDINAL'), ('1', 'CARDINAL'), ('california', 'GPE')]
# []
# []
# [("martin shkreli's", 'PERSON')]
# [('2017', 'DATE')]
# [('new york', 'GPE')]
# []
# [('equifax', 'ORG')]
# [('new york', 'GPE')]
# [('texas', 'GPE')]
# [('shark kills', 'PERSON'), ('australia', 'GPE')]
# [('army', 'ORG'), ('two', 'CARDINAL')]
# [('new united airlines', 'ORG'), ('last-minute', 'TIME')]
# [('swab', 'NORP'), ('nabs', 'NORP'), ("vanessa marcotte's", 'PERSON')]
# [('cleveland', 'GPE')]
# []
# [('decades', 'DATE'), ('elite connecticut school', 'ORG')]
# [('wisconsin', 'GPE'), ('trump', 'PERSON')]
# [('7', 'CARDINAL'), ('arkansas', 'GPE'), ('this month', 'DATE')]
# []
# [('2', 'CARDINAL')]
# []
# [('cops hunt', 'PERSON')]
# [('charleston', 'GPE'), ('dylann roof', 'PERSON')]
# [('night', 'TIME')]
# [('156', 'CARDINAL'), ('dallas', 'GPE')]
# [('second', 'ORDINAL'), ('florida', 'GPE')]
# [('canada', 'GPE')]
# [('indian', 'NORP'), ('u.s.', 'GPE')]
# []
# [('passenger disarms knife', 'ORG'), ('london', 'GPE')]
# [('patz', 'PERSON'), ('at least 25 years', 'DATE')]
# [('california', 'GPE'), ('3', 'CARDINAL')]
# [('arkansas', 'GPE'), ('ag', 'ORG')]
# [('texas', 'GPE'), ('north lake', 'LOC')]
# [('3', 'CARDINAL'), ('more than a dozen', 'CARDINAL'), ('massachusetts', 'GPE')]
# [('u.s.', 'GPE'), ('canadian', 'NORP')]
# []
# [('nippon airways', 'ORG'), ('los angeles', 'GPE')]
# []
# [('1', 'CARDINAL'), ('7', 'CARDINAL'), ('san diego-area', 'GPE')]
# [('1', 'CARDINAL'), ('3', 'CARDINAL')]
# [('at least 10', 'CARDINAL'), ('u.s.', 'GPE')]
# [('rip', 'ORG'), ('texas', 'GPE'), ('midwest', 'LOC')]
# [('texas', 'GPE'), ('mexico', 'GPE')]
# [('pennsylvania', 'GPE')]
# [('6th', 'ORDINAL')]
# [('up to 60', 'CARDINAL'), ('bart', 'ORG')]
# [('arkansas', 'GPE'), ('2', 'CARDINAL'), ('monday', 'DATE')]
# [('hero firefighter', 'PERSON')]
# []
# [('arkansas', 'GPE'), ('hours', 'TIME')]
# [('u.s.', 'GPE')]
# [('city council', 'ORG'), ('lawmaker', 'PERSON')]
# []
# [('24 years later', 'DATE')]
# [('new yorker', 'PERSON'), ('asian', 'NORP')]
# [('34,500', 'MONEY')]
# []
# [('north dakota', 'GPE')]
# [('florida', 'GPE'), ('10', 'CARDINAL')]
# [('cops hunt', 'PERSON')]
# [('white house', 'ORG')]
# [('san diego', 'GPE')]
# []
# [('oklahoma', 'GPE')]
# []
# [('new mexico', 'GPE'), ('qurans', 'NORP')]
# []
# [('10 years', 'DATE')]
# []
# [('california', 'GPE')]
# [('gunman robs', 'PERSON'), ('florida blood bank', 'ORG')]
# [('newsweek', 'ORG'), ('abc', 'ORG')]
# [('justin', 'ORG')]
# [("tim kaine's", 'PERSON')]
# [('florida', 'GPE')]
# [('at least 4', 'CARDINAL'), ('mississippi', 'GPE')]
# [('4', 'CARDINAL'), ('california', 'GPE')]
# []
# [('5 years', 'DATE')]
# [('cincinnati', 'GPE'), ('one', 'CARDINAL'), ('15', 'CARDINAL')]
# [('oakland', 'GPE'), ('calif', 'GPE')]
# [('new jersey', 'GPE'), ('u.s.', 'GPE')]
# []
# []
# []
# [('london', 'GPE')]
# []
# [('homeowner', 'ORG')]
# [('hotel pool leaves', 'ORG'), ('1', 'CARDINAL'), ('12', 'CARDINAL')]
# [('louisiana', 'GPE'), ('40 years', 'DATE')]
# [('atlanta', 'GPE')]
# [('2', 'CARDINAL'), ('chicago', 'GPE')]
# []
# []
# [('2', 'CARDINAL')]
# [('ferrari', 'ORG')]
# []
# [('stole $40,000', 'MONEY')]
# [('2', 'CARDINAL'), ('miami', 'GPE')]
# [('oklahoma', 'GPE'), ('3', 'CARDINAL')]
# []
# []
# []
# []
# []
# [('boston', 'GPE')]
# []
# [('minnesota', 'GPE')]
# [('3', 'CARDINAL')]
# [('amanda knox', 'PERSON')]
# []
# [('texas', 'GPE'), ('flung', 'PERSON')]
# [('florida', 'GPE'), ('2', 'CARDINAL')]
# [('baltimore', 'GPE'), ('34', 'CARDINAL')]
# [('indiana', 'GPE')]
# [('two', 'CARDINAL'), ('baltimore', 'GPE')]
# []
# [('colorado', 'GPE'), ('dylan redwine', 'PERSON'), ('2012', 'DATE')]
# [('10', 'CARDINAL'), ('texas', 'GPE')]
# [('deadly weekend', 'DATE'), ('chicago', 'GPE')]
# [('n.j.', 'ORG')]
# [('don diva', 'PERSON')]
# [('at least 3', 'CARDINAL'), ('honolulu', 'GPE')]
# [('amsterdam airbnb host', 'PERSON'), ('south african', 'NORP')]
# [('second', 'ORDINAL'), ('4', 'CARDINAL'), ('pennsylvania', 'GPE')]
# [('pennsylvania', 'GPE')]
# []
# [('weekend', 'DATE'), ('3', 'CARDINAL'), ('texas', 'GPE')]
# [('toronto', 'GPE'), ('china', 'GPE')]
# [('london', 'GPE')]
# [('3', 'CARDINAL'), ('massachusetts', 'GPE')]
# [('idaho', 'GPE'), ('utah', 'GPE')]
# []
# []
# [('utah', 'GPE')]
# [('30', 'CARDINAL'), ('u.s.', 'GPE')]
# []
# []
# [('1', 'CARDINAL'), ('charleston', 'GPE')]
# []
# []
# [('steubenville football', 'ORG'), ('2012', 'DATE')]
# [('texas', 'GPE')]
# [('2', 'CARDINAL'), ('florida', 'GPE'), ('one', 'CARDINAL'), ('us', 'GPE')]
# [('charles manson', 'PERSON')]
# [('mayhem', 'ORG')]
# [('heather heyer', 'PERSON'), ('charlottesville', 'GPE')]
# [('2', 'CARDINAL')]
# [('charlottesville', 'GPE'), ('1', 'CARDINAL')]
# []
# []
# [('colorado', 'GPE')]
# [('hundreds', 'CARDINAL')]
# [('4th of july', 'DATE')]
# [('california', 'GPE')]
# [('louisiana', 'ORG')]
# []
# [('portland', 'GPE')]
# [('8', 'CARDINAL'), ('mississippi', 'GPE')]
# [('two', 'CARDINAL'), ('portland', 'GPE')]
# [('portland hate', 'ORG'), ('muslims', 'NORP'), ('u.s.', 'GPE')]
# [('2', 'CARDINAL'), ('muslim', 'NORP'), ('portland', 'GPE')]
# [('2', 'CARDINAL'), ('pennsylvania', 'GPE'), ('opioid', 'ORG')]
# [('3', 'CARDINAL')]
# [('four', 'CARDINAL'), ('ted wheeler', 'PERSON'), ('today', 'DATE')]
# [('2', 'CARDINAL'), ('islamic', 'NORP')]
# [('honolulu', 'GPE')]
# [('3 years', 'DATE')]
# []
# [("carolina herrera's", 'PRODUCT')]
# [('k9', 'CARDINAL')]
# [('2015', 'DATE'), ('amtrak', 'ORG')]
# [('u.s.', 'GPE')]
# []
# [('san diego police', 'ORG')]
# []
# [('hours', 'TIME'), ('orlando', 'GPE')]
# [('portland', 'GPE')]
# [('kentucky', 'GPE')]
# [('florida', 'GPE')]
# [('pennsylvania', 'GPE')]
# [('dozens', 'CARDINAL'), ('arkansas', 'GPE')]
# [('tracy sin-yee', 'PERSON'), ('bronx hospital', 'FAC')]
# [('5 years', 'DATE'), ('miller', 'ORG'), ('alabama', 'GPE')]
# []
# [('california', 'GPE')]
# [('america', 'GPE')]
# []
# [('84', 'CARDINAL'), ('new hampshire', 'GPE')]
# [('alabama', 'GPE'), ('first', 'ORDINAL'), ('34 years earlier', 'DATE')]
# [('u.s.', 'GPE'), ('54,789', 'MONEY')]
# [('trucker', 'ORG')]
# [('5', 'CARDINAL'), ('week 1', 'DATE')]
# [('toddlers', 'ORG')]
# [('anti-muslim', 'NORP'), ("san bernardino's", 'GPE')]
# [('subway', 'ORG')]
# [('the american correctional association', 'ORG')]
# []
# [('california', 'GPE')]
# []
# [('10', 'CARDINAL'), ('boston', 'GPE')]
# []
# [('2', 'CARDINAL'), ('texas', 'GPE'), ('last week', 'DATE'), ('only 1', 'CARDINAL')]
# [('4', 'CARDINAL'), ('california', 'GPE')]
# []
# []
# []
# [('new york', 'GPE'), ('brooklyn', 'GPE')]
# [('911', 'CARDINAL')]
# []
# [('vatican', 'GPE')]
# []
# [('topless protester', 'ORG'), ('bill cosby', 'PERSON')]
# [('los angeles', 'GPE'), ('second', 'ORDINAL'), ('a week', 'DATE')]
# [('up to 100', 'CARDINAL')]
# [('bill cosby', 'PERSON'), ('accuser', 'PERSON')]
# []
# []
# [('chicago', 'GPE'), ('weekend', 'DATE')]
# []
# []
# []
# []
# [('allison mack', 'PERSON')]
# []
# [('2', 'CARDINAL'), ('florida', 'GPE'), ('chinese', 'NORP')]
# []
# []
# [('police arrest waffle house', 'ORG')]
# []
# [('cosby', 'ORG')]
# [('2', 'CARDINAL'), ('arizona', 'GPE')]
# [("dylann roof's", 'PERSON')]
# []
# []
# [('world', 'ORG'), ('costco', 'ORG')]
# [('austin', 'PERSON')]
# []
# [('san antonio', 'GPE'), ('austin bombings', 'PERSON'), ('fbi', 'ORG')]
# [('texas', 'GPE')]
# [("austin bomber's", 'PERSON')]
# [('austin', 'PERSON')]
# [('austin', 'PERSON')]
# []
# [('u.s.', 'GPE'), ('iranians', 'NORP')]
# []
# [('two', 'CARDINAL'), ('islamophobic', 'NORP')]
# [("pulse nightclub shooter's", 'PERSON'), ('fbi', 'ORG')]
# [("larry nassar's", 'PERSON')]
# [('washington', 'GPE'), ('d.c.', 'GPE')]
# [('salman', 'PERSON')]
# []
# [('pulse nightclub shooter’s', 'PERSON')]
# [('nikolas cruz', 'PERSON')]
# []
# []
# [('waffle house', 'ORG')]
# [('dallas', 'GPE'), ('2', 'CARDINAL')]
# [('138', 'CARDINAL'), ('last year', 'DATE'), ('u.s.', 'GPE')]
# []
# [('george zimmerman', 'PERSON'), ('trayvon martin', 'PERSON')]
# [('s.c.', 'GPE'), ('burn cross', 'ORG'), ('fbi', 'ORG')]
# [('lo', 'PERSON'), ("chris brown's", 'PERSON')]
# [('10 and 11', 'DATE')]
# [('nurse', 'ORG')]
# []
# [('7', 'CARDINAL'), ('australia', 'GPE'), ('1996', 'DATE')]
# [('golden state killer', 'ORG'), ('four', 'CARDINAL')]
# [('california high school', 'ORG'), ('1', 'CARDINAL')]
# []
# [('larry nassar', 'PERSON')]
# [('manhattan', 'GPE'), ('marijuana', 'ORG')]
# [('wwf', 'PERSON'), ('california', 'GPE')]
# [('hospice', 'ORG')]
# [('the santa fe high school', 'ORG')]
# []
# [('florida', 'GPE'), ('2', 'CARDINAL'), ('panama city', 'GPE')]
# [('maryland', 'GPE'), ('3', 'CARDINAL')]
# [('2', 'CARDINAL'), ('indiana', 'GPE')]
# [('muslim', 'NORP'), ('mcdonald', 'ORG')]
# []
# [("georgia highway sniper '", 'ORG')]
# [('$1.2 million', 'MONEY')]
# [('indian', 'NORP')]
# [('drone', 'ORG'), ('fbi', 'ORG')]
# []
# []
# [('nassar', 'ORG'), ('first', 'ORDINAL')]
# [('2', 'CARDINAL'), ('arizona', 'GPE')]
# [('bill cosby', 'PERSON')]
# [('bill cosby', 'PERSON')]
# []
# [('patton oswalt', 'ORG'), ("michelle mcnamara's", 'PERSON')]
# [('zero', 'CARDINAL')]
# [('louisiana', 'GPE'), ('texas', 'GPE')]
# []
# []
# [('texas', 'GPE'), ('16 years', 'DATE')]
# [('57', 'CARDINAL'), ('texas', 'GPE'), ('meth', 'GPE')]
# [('janice dickinson', 'PERSON'), ('cosby', 'ORG')]
# [('9', 'CARDINAL'), ('georgia', 'GPE')]
# [('white supremacist', 'ORG'), ('charlottesville', 'GPE')]
# []
# [('veterinarian', 'ORG')]
# [('las vegas', 'GPE')]
# [('camille cosby', 'PERSON')]
# [('1', 'CARDINAL')]
# [('1', 'CARDINAL'), ('nashville', 'GPE'), ('tennessee', 'GPE')]
# [('badass grandpa', 'PERSON')]
# []
# []
# [('49', 'CARDINAL'), ('orlando', 'GPE')]
# []
# []
# []
# []
# []
# [('pearson botches mississippi testing', 'ORG'), ('mississippi', 'LOC')]
# []
# [('10', 'CARDINAL')]
# []
# []
# []
# []
# [('america', 'GPE'), ('3', 'CARDINAL')]
# []
# []
# []
# []
# [('nyc', 'PERSON'), ('la', 'PERSON')]
# []
# [('teachers union', 'ORG')]
# [('california', 'GPE')]
# [('one', 'CARDINAL'), ('#', 'CARDINAL')]
# [('ken ham', 'PERSON'), ('miley cyrus', 'PERSON')]
# []
# []
# []
# [('california', 'GPE')]
# []
# [('california', 'GPE')]
# []
# []
# [('second', 'ORDINAL')]
# []
# []
# [('july fourth', 'DATE'), ('united states', 'GPE')]
# [('2', 'CARDINAL')]
# [('west virginia', 'GPE')]
# []
# [('west virginia', 'GPE')]
# []
# [('kabul', 'GPE'), ('california', 'GPE'), ('this summer', 'DATE')]
# []
# []
# [('l.a.', 'GPE')]
# [('week', 'DATE')]
# [('community college', 'ORG'), ('american', 'NORP')]
# []
# []
# []
# []
# [('betsy devos', 'PERSON')]
# [('detroit', 'GPE')]
# [("happy mother's", 'PERSON')]
# []
# []
# [('10', 'CARDINAL')]
# [('switzerland', 'GPE')]
# [('los angeles', 'GPE')]
# [('washington', 'GPE'), ('d.c.', 'GPE')]
# []
# [('donald trump', 'PERSON')]
# [('pearson', 'PERSON')]
# []
# []
# []
# []
# [("jonathan kozol's", 'PERSON')]
# [('harvard', 'ORG')]
# []
# []
# [('calif.', 'GPE'), ('anti-muslim', 'NORP')]
# []
# []
# []
# []
# [('summer', 'DATE')]
# []
# [('john white', 'PERSON'), ('a may 30, 2017', 'DATE')]
# [('trump', 'PERSON')]
# []
# []
# []
# []
# []
# [('k-12', 'CARDINAL')]
# [('notre dame', 'ORG'), ('2017', 'DATE')]
# []
# []
# [('one', 'CARDINAL')]
# [('chicago', 'GPE'), ('may 25', 'DATE')]
# [('6', 'CARDINAL')]
# [('529s', 'CARDINAL')]
# [('the u.s. department of education', 'ORG')]
# []
# [('seven', 'CARDINAL')]
# []
# [('betsy', 'PERSON')]
# []
# [('california', 'GPE'), ('trump', 'PERSON')]
# [('illinois', 'GPE'), ('$75m', 'MONEY')]
# [('john dewey', 'PERSON')]
# []
# []
# [('west virginia', 'GPE'), ('first', 'ORDINAL'), ('28 years', 'DATE')]
# [("harry potter'", 'PERSON'), ('19 years later', 'DATE')]
# []
# []
# [('california', 'GPE')]
# []
# []
# []
# [('first', 'ORDINAL')]
# []
# []
# []
# [('5', 'CARDINAL')]
# [('11', 'CARDINAL')]
# []
# [('california', 'GPE')]
# []
# [('monday', 'DATE'), ('2', 'CARDINAL')]
# []
# []
# []
# []
# []
# [('4', 'CARDINAL')]
# [('america', 'GPE'), ('houston', 'GPE')]
# []
# [('tomorrow', 'DATE')]
# []
# [('100,000', 'MONEY')]
# []
# []
# []
# []
# [('senate', 'ORG'), ('betsy', 'PERSON')]
# [("the new york times magazine's", 'ORG')]
# []
# [('america', 'GPE'), ('2', 'CARDINAL'), ('five', 'CARDINAL')]
# []
# []
# []
# []
# []
# []
# []
# []
# [('three to five', 'CARDINAL')]
# []
# []
# [('5', 'CARDINAL')]
# []
# []
# []
# []
# [('zero', 'CARDINAL')]
# [('converted city bus brings', 'ORG')]
# [('alec', 'PERSON'), ('betsy', 'PERSON'), ('2017', 'DATE')]
# [('indian', 'NORP')]
# []
# [('parcc', 'PERSON')]
# [('texas', 'GPE')]
# [('year', 'DATE')]
# []
# [('5', 'CARDINAL')]
# []
# [('new orleans', 'GPE'), ('four-year', 'DATE')]
# []
# [('yale law school', 'ORG')]
# []
# []
# []
# []
# []
# [('new orleans', 'GPE')]
# [('four years later', 'DATE')]
# []
# [('james alex', 'PERSON'), ('jr', 'PERSON')]
# []
# [('texas', 'GPE')]
# []
# [('la', 'PERSON')]
# []
# []
# []
# [('the new jersey lotto', 'ORG')]
# []
# [('betsy devos', 'PERSON'), ('2015-16', 'DATE')]
# []
# []
# [('k12 schools', 'PERSON')]
# [('hamilton', 'PERSON'), ('voltaire', 'PERSON')]
# [('jerry falwell', 'PERSON'), ('jr', 'GPE'), ('u.s.', 'GPE')]
# []
# []
# []
# []
# [('brexit', 'GPE'), ('us', 'GPE')]
# [('trump', 'PERSON')]
# [('trump', 'GPE'), ('america', 'GPE')]
# [('donald j. trump', 'PERSON')]
# []
# []
# [('daniel rabuzzi', 'PERSON')]
# []
# []
# [('supreme court', 'ORG')]
# [('thousands', 'CARDINAL'), ('american', 'NORP')]
# []
# [('eileen', 'PERSON')]
# [('three', 'CARDINAL')]
# []
# []
# []
# [('new york', 'GPE')]
# [('fake news', 'ORG'), ('social media', 'ORG'), ('u.s.', 'GPE')]
# []
# [('betsy devos', 'PERSON')]
# []
# [('30 days', 'DATE'), ('october 2016', 'DATE')]
# [('three', 'CARDINAL')]
# []
# []
# []
# [('asian', 'NORP'), ('americans', 'NORP')]
# []
# []
# []
# [('answering eisenhower', 'ORG')]
# [('d.c.', 'GPE'), ('naep', 'GPE'), ('rhee/henderson', 'ORG')]
# [('the united states', 'GPE')]
# [('today', 'DATE')]
# []
# [('abc', 'ORG')]
# [("paul tough's", 'PERSON')]
# []
# []
# []
# []
# []
# []
# []
# [('michigan', 'GPE')]
# []
# []
# []
# [('california', 'GPE')]
# [('week', 'DATE')]
# []
# [('bronx', 'GPE')]
# [('today', 'DATE')]
# [('30 days - may 2016', 'DATE')]
# []
# []
# []
# []
# []
# [('massachusetts', 'GPE')]
# [('america', 'GPE'), ('tomorrow', 'DATE')]
# [('pa charter', 'ORG')]
# [('thomas mcgovern', 'PERSON')]
# []
# []
# []
# [('arkansas', 'GPE'), ('jim', 'PERSON'), ('alice walton', 'PERSON'), ('1,835,000', 'MONEY'), ('massachusetts', 'GPE')]
# [('8', 'CARDINAL'), ('u.s.', 'GPE')]
# []
# []
# [('11', 'CARDINAL')]
# [('4', 'CARDINAL')]
# [('kaepernick', 'PERSON')]
# [('modern day', 'DATE')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('asian americans', 'NORP')]
# [('field guide', 'ORG')]
# [('america', 'GPE')]
# []
# []
# [('12th', 'DATE')]
# []
# []
# []
# [('8', 'CARDINAL')]
# [('trump', 'PERSON')]
# []
# [('thousands', 'CARDINAL')]
# []
# [('pearson germ', 'PERSON'), ('philippines', 'GPE')]
# [('ted dintersmith', 'PERSON')]
# []
# []
# []
# [('newark', 'GPE')]
# [('trinity lutheran v. comer', 'PERSON'), ('7', 'CARDINAL')]
# []
# []
# []
# []
# [('trump', 'PERSON')]
# [('pearson', 'PERSON')]
# []
# [('amsterdam', 'ORG')]
# []
# []
# []
# []
# []
# [('california', 'GPE'), ('first', 'ORDINAL')]
# [('gwen morgan', 'PERSON')]
# []
# [('l.a. school board', 'ORG')]
# []
# [('seattle', 'GPE'), ('first day', 'DATE')]
# [('donald trump & vaccines', 'ORG')]
# [('america', 'GPE')]
# []
# [('africa', 'LOC')]
# []
# [('gop', 'ORG')]
# []
# [('annual', 'DATE')]
# [('betsy', 'PERSON')]
# [('5', 'CARDINAL')]
# [('conservatives', 'NORP')]
# [('early in the morning', 'TIME'), ('lawmaker', 'PERSON')]
# []
# [('betsy devos', 'PERSON')]
# [('pennsylvania', 'GPE')]
# [('tennessee', 'GPE'), ('jessi bohon', 'PERSON')]
# []
# []
# [('betsy', 'PERSON'), ('michigan', 'GPE'), ('republicans', 'NORP')]
# []
# [('asian americans', 'NORP'), ('americans', 'NORP')]
# [('betsy devos', 'PERSON')]
# [('donald trump', 'PERSON')]
# [('betsy devos', 'PERSON')]
# []
# []
# []
# []
# []
# [('thousands', 'CARDINAL')]
# []
# [('hannah skandera', 'PERSON')]
# [('pearson', 'PERSON')]
# [('toronto', 'GPE'), ('u.s.', 'GPE')]
# [('9', 'CARDINAL'), ('twenty', 'CARDINAL')]
# [('latin america', 'LOC')]
# []
# []
# []
# [('100,000', 'CARDINAL')]
# [('1', 'CARDINAL')]
# [('hank aaron', 'PERSON')]
# []
# []
# []
# [('ed tech', 'PERSON')]
# []
# []
# [('christian', 'NORP'), ('christians', 'NORP')]
# []
# [('just four days', 'DATE')]
# []
# []
# []
# []
# [('florida', 'GPE')]
# [('west virginia', 'GPE')]
# [('west virginia', 'GPE'), ('fed', 'ORG')]
# []
# [('california', 'GPE')]
# [('bang', 'PERSON')]
# [('south carolina', 'GPE')]
# [('one', 'CARDINAL')]
# [('gop', 'ORG')]
# []
# []
# [('berkleeice & bein sports', 'ORG'), ('america', 'GPE')]
# []
# [('shanghai', 'GPE')]
# []
# [('detroit', 'GPE')]
# [('american', 'NORP')]
# []
# []
# [('30 days', 'DATE')]
# [('texas', 'GPE')]
# []
# []
# [('congress', 'ORG'), ('250', 'MONEY')]
# [('swarm kentucky', 'PERSON')]
# []
# []
# []
# []
# []
# []
# [('devos department', 'ORG')]
# [('bridgepoint sec', 'PERSON')]
# []
# []
# []
# [("robert putnam's", 'PERSON'), ('american', 'NORP')]
# [('devos department', 'ORG')]
# [('2', 'CARDINAL')]
# []
# []
# []
# [('texas', 'GPE')]
# [('columbia university', 'ORG')]
# []
# []
# []
# []
# []
# []
# [('arizona', 'GPE')]
# []
# [('cheryl williams', 'PERSON')]
# []
# [('california', 'GPE')]
# [('american', 'NORP'), ('iraq', 'GPE')]
# [('two', 'CARDINAL')]
# []
# []
# [('america', 'GPE')]
# []
# [('10', 'CARDINAL')]
# [('10', 'CARDINAL')]
# [('one', 'CARDINAL'), ('california', 'GPE')]
# []
# []
# []
# []
# [('justin', 'ORG')]
# []
# [('chinese', 'NORP'), ('chinese', 'NORP')]
# []
# [("sesame street'", 'ORG'), ('$100 million', 'MONEY')]
# [('texas', 'GPE')]
# [('new york city', 'GPE')]
# [('first', 'ORDINAL')]
# [('new mexico charter school', 'ORG'), ('15 years', 'DATE')]
# [('chicagoans', 'NORP')]
# []
# [('los angeles', 'GPE')]
# []
# [('louisiana', 'GPE'), ('five-year-old', 'DATE')]
# [('harvard', 'ORG')]
# [('5', 'CARDINAL')]
# [('california', 'GPE')]
# []
# [('chuck e. cheese', 'PERSON')]
# []
# []
# [('pennsylvania', 'GPE'), ('500', 'CARDINAL')]
# []
# [('connections education & nexus academy', 'ORG')]
# [('summer', 'DATE')]
# [('ohio', 'GPE')]
# []
# [('peter cunningham', 'PERSON')]
# [('5', 'CARDINAL')]
# [('eagle', 'ORG')]
# [('kentucky', 'GPE')]
# []
# []
# [('3', 'CARDINAL')]
# []
# []
# [('matt damon', 'PERSON')]
# []
# []
# []
# []
# [('summer', 'DATE')]
# [('california', 'GPE')]
# [('laura ingraham', 'PERSON'), ('david hogg', 'PERSON'), ('irvine', 'GPE')]
# [('the morning', 'TIME')]
# []
# [('puerto rico', 'GPE'), ('283', 'CARDINAL'), ('this summer', 'DATE')]
# []
# [('des moines', 'GPE')]
# [('america', 'GPE')]
# []
# [('thursday', 'DATE'), ('dominic casulli', 'PERSON'), ('1', 'CARDINAL')]
# [('university of wisconsin-inferior', 'ORG')]
# []
# [('oklahoma', 'GPE'), ('march', 'DATE')]
# [('fox news', 'ORG'), ('republican', 'NORP'), ('robert mueller', 'PERSON')]
# [('ireland', 'GPE')]
# [('the supreme court', 'ORG')]
# [('howard stern', 'PERSON'), ('david letterman', 'PERSON')]
# []
# [('alaska', 'GPE')]
# [('north carolina', 'GPE')]
# [('american', 'NORP'), ('5', 'CARDINAL')]
# [('hillary clinton', 'PERSON'), ('russian', 'NORP'), ('yale', 'ORG')]
# [('at&t', 'ORG'), ('trump', 'PERSON')]
# [('booyah', 'ORG'), ('obama', 'GPE')]
# [('trump white house', 'PERSON')]
# [('trump defends gina haspel', 'PERSON'), ('cia', 'ORG')]
# []
# [('democrats', 'NORP')]
# [('giuliani', 'ORG'), ('mueller', 'PERSON'), ('fbi', 'ORG')]
# [('years', 'DATE')]
# [('spanish', 'NORP')]
# [('blake', 'PERSON')]
# [('epa', 'ORG')]
# [('garry kasparov', 'PERSON'), ('donald trump', 'PERSON'), ('russian', 'NORP')]
# [('trump', 'PERSON')]
# [('california authority', 'ORG'), ('state', 'ORG')]
# [('federal court', 'ORG')]
# []
# []
# [('trump', 'PERSON'), ('scottish', 'NORP')]
# [('vietnam', 'GPE'), ('u.s.', 'GPE')]
# [('ryan zinke', 'PERSON')]
# [('pennsylvania', 'GPE')]
# [('just one-third', 'CARDINAL'), ('americans', 'NORP')]
# []
# [('msnbc', 'ORG')]
# [('texans', 'NORP')]
# [('texas', 'GPE')]
# [('roger stone', 'PERSON')]
# [('democrats', 'NORP')]
# [('hillary clinton', 'PERSON'), ("andrew cuomo's", 'PERSON')]
# [('the supreme court', 'ORG')]
# [('first', 'ORDINAL'), ('gop', 'ORG'), ('indiana', 'GPE')]
# [('west virginia', 'GPE'), ('senate', 'ORG'), ('n’t receive a penny', 'MONEY'), ('west virginians', 'NORP')]
# [('trump', 'GPE'), ('iran', 'GPE'), ('russia', 'GPE')]
# [('santa fe', 'ORG'), ('1 month', 'DATE')]
# []
# []
# [('oliver north blames', 'PERSON')]
# [('meek mill', 'PERSON')]
# [('u.s.', 'GPE'), ('iran', 'GPE')]
# [('don blankenship', 'PERSON'), ('patrick morrisey', 'PERSON'), ('west virginia', 'GPE'), ('senate', 'ORG')]
# [("new york's", 'GPE')]
# [('ohio', 'GPE')]
# [("jim carrey's", 'PERSON'), ("kent state '", 'PERSON')]
# [('mark kelly', 'PERSON'), ('trump', 'PERSON'), ('nra', 'ORG')]
# [('gop', 'ORG')]
# [('houston', 'GPE')]
# [('gop rep', 'ORG'), ('white house', 'ORG')]
# [('trump jr.', 'PERSON'), ('gulf', 'LOC'), ('2016', 'DATE')]
# [("trump misspells melania's", 'PERSON')]
# [('jeff sessions', 'PERSON'), ('exceptional power', 'ORG')]
# [('jimmy kimmel', 'PERSON'), ('texas school', 'ORG')]
# [("paul ryan's", 'PERSON')]
# [('senate', 'ORG'), ('republicans', 'NORP'), ('shun don blankenship', 'PERSON'), ('west virginia', 'GPE')]
# []
# [('texas', 'GPE'), ('dan patrick', 'PERSON')]
# [('americans', 'NORP'), ('russia', 'GPE')]
# [('u.s.', 'GPE'), ('china', 'GPE'), ('treasury', 'ORG'), ('steve mnuchin', 'PERSON')]
# []
# [('edward snowden', 'PERSON'), ('vladimir putin', 'PERSON')]
# [('trump', 'PERSON'), ('cia', 'ORG')]
# [('trump', 'PERSON'), ('amazon', 'ORG')]
# [('dems', 'NORP'), ('trump admin', 'PERSON'), ('myanmar', 'GPE')]
# []
# [('gop', 'ORG'), ('north carolina', 'GPE')]
# [('giuliani', 'ORG'), ('mueller', 'PERSON'), ('september', 'DATE')]
# [('michael cohen', 'PERSON')]
# [('stephanie kelton', 'PERSON'), ('washington', 'GPE')]
# [('mitch mcconnell', 'PERSON')]
# [('trump', 'ORG'), ('iran', 'GPE')]
# [('fbi', 'ORG'), ('putin', 'PERSON'), ('trump jr.', 'PERSON')]
# [('giuliani', 'ORG'), ('trump', 'PERSON'), ('michael cohen', 'PERSON')]
# [('trump', 'PERSON')]
# [('texas', 'GPE'), ('santa fe school', 'ORG')]
# [('joe scarborough', 'PERSON'), ('trump', 'PERSON')]
# [('gop', 'ORG')]
# [('bernie sanders', 'PERSON')]
# [('mike pompeo', 'PERSON'), ('iran', 'GPE')]
# [('senate', 'ORG')]
# [('congress', 'ORG')]
# [('fbi', 'ORG')]
# [('eric schneiderman', 'PERSON')]
# [('lupe valdez', 'PERSON'), ('texas', 'GPE')]
# [("michael cohen's", 'PERSON')]
# [('stacey abrams', 'PERSON'), ('democratic', 'NORP'), ('georgia', 'GPE')]
# [('scott pruitt justify', 'ORG'), ('first', 'ORDINAL'), ('epa', 'ORG')]
# [('gina ortiz jones', 'PERSON'), ('democratic', 'NORP'), ('texas', 'GPE')]
# [('ireland', 'GPE'), ('trump', 'PERSON')]
# [('fighter', 'ORG'), ('amy mcgrath', 'ORG'), ('democratic', 'NORP'), ('kentucky', 'GPE')]
# [('senate', 'ORG')]
# []
# [('coke', 'ORG'), ('prostitute yacht party', 'ORG')]
# [('north korea', 'GPE'), ('kim jong un', 'PERSON')]
# [('tomi lahren', 'PERSON')]
# [('ohio', 'GPE')]
# [('michael cohen', 'PERSON'), ('500,000', 'MONEY'), ('russian', 'NORP')]
# []
# [('house', 'ORG'), ('republicans', 'NORP')]
# [('democrats', 'NORP'), ('fbi', 'ORG')]
# [('gop', 'ORG'), ('georgia', 'GPE')]
# []
# [('democrats', 'NORP'), ('fbi', 'ORG')]
# [('rudy giuliani', 'PERSON'), ('trump', 'PERSON')]
# [('kentucky', 'GPE'), ('gop', 'ORG')]
# [('alabama', 'ORG')]
# [('kim', 'PERSON')]
# [('cynthia nixon', 'PERSON')]
# [('white house', 'ORG')]
# [('trump', 'PERSON'), ('kim jong un', 'PERSON'), ('north korea', 'GPE')]
# [('facebook', 'ORG')]
# [('texas', 'GPE')]
# [('scott pruitt', 'PERSON')]
# [("mike pence's", 'PERSON'), ('house', 'ORG')]
# [('kentucky', 'GPE'), ('1 day', 'DATE')]
# [('marines', 'ORG')]
# [('koch', 'PERSON'), ('one', 'CARDINAL')]
# [('west hollywood', 'GPE')]
# [('one', 'CARDINAL')]
# [('house', 'ORG'), ('democrats', 'NORP')]
# [('betsy devos stirs', 'PERSON')]
# [('iran', 'GPE')]
# [('6', 'CARDINAL'), ('fbi', 'ORG'), ('sue alex jones', 'PERSON')]
# []
# [('chrissy teigen', 'PERSON'), ('donald trump', 'PERSON')]
# [('u.s.', 'GPE')]
# []
# [('michelle obama', 'PERSON')]
# [('sarah', 'PERSON')]
# [('democratic', 'NORP'), ('west virginia', 'GPE'), ('4', 'CARDINAL'), ('this election day', 'DATE')]
# [('lawmaker', 'ORG'), ('trump', 'PRODUCT')]
# [('roger stone', 'PERSON'), ('hillary clinton', 'PERSON'), ('wikileaks', 'PERSON')]
# [('gop', 'ORG'), ('russia', 'GPE')]
# [('chinese', 'NORP'), ('today', 'DATE')]
# [('iran', 'GPE')]
# [('georgia', 'GPE'), ('gop', 'ORG')]
# [('georgia', 'GPE'), ('the democratic party', 'ORG')]
# [('california', 'GPE')]
# [('nra', 'ORG')]
# [('kentucky', 'GPE')]
# [('trump-kim jong un', 'PERSON')]
# [('giuliani', 'ORG'), ('russian', 'NORP')]
# [('seth meyers', 'PERSON'), ('michael cohen', 'PERSON')]
# [('michael cohen', 'PERSON')]
# [('democrats', 'NORP')]
# [('michael curry', 'PERSON'), ('christian', 'NORP'), ('white house', 'ORG'), ('reclaim jesus', 'PERSON')]
# [('jack johnson', 'PERSON')]
# []
# []
# []
# [("donald trump's", 'PERSON')]
# []
# [('house', 'ORG'), ('republican', 'NORP')]
# [('trump', 'PERSON')]
# []
# [('orrin hatch', 'PERSON'), ("john mccain's", 'PERSON')]
# [('more than 100', 'CARDINAL'), ('gina', 'GPE')]
# [('catholic', 'NORP')]
# [('2018', 'DATE')]
# [('white house', 'ORG'), ('congress', 'ORG'), ('$15 billion', 'MONEY')]
# [('non-christian', 'NORP'), ('2', 'CARDINAL'), ('iraqi', 'NORP'), ('christians', 'NORP')]
# [('nra', 'ORG'), ('texas', 'GPE')]
# [("tulsi gabbard's", 'ORG'), ('syria', 'GPE'), ('hawaii teachers union', 'ORG')]
# [('jared kushner', 'PERSON')]
# [('arizona gop congressional', 'ORG')]
# [('mitch mcconnell', 'PERSON')]
# [('lucy mcbath', 'PERSON'), ('georgia house', 'ORG')]
# [('democratic house', 'ORG'), ('texas', 'GPE')]
# []
# [('ryan zinke', 'PERSON'), ('two', 'CARDINAL')]
# [('nra', 'ORG')]
# [('bill de blasio', 'PERSON'), ('nypd', 'NORP')]
# [('dhs head', 'PERSON'), ('intel', 'ORG'), ('russia', 'GPE')]
# [('eric schneiderman', 'PERSON')]
# [('white house', 'ORG')]
# [('pan ted cruz', 'PERSON'), ('santa fe school', 'ORG')]
# [('trump', 'PERSON'), ('waffle house', 'ORG'), ('james shaw jr', 'PERSON')]
# [('tom steyer', 'PERSON')]
# [('meghan mccain', 'PERSON'), ('white house', 'ORG')]
# [('white house', 'ORG'), ('gaza', 'GPE'), ('hamas', 'ORG')]
# [('epa', 'ORG'), ("scott pruitt's", 'PERSON')]
# [("john mccain '", 'PERSON')]
# [('gina haspel', 'PERSON'), ('cia', 'ORG')]
# [('trump', 'PERSON')]
# [('jake tapper rips', 'PERSON'), ('tom mcinerney', 'PERSON'), ('john mccain', 'PERSON')]
# [('iran', 'GPE')]
# [('christmas', 'DATE')]
# [('tennessee county', 'GPE'), ('election night', 'TIME')]
# [('pennsylvania', 'GPE')]
# []
# [('eric greitens', 'PERSON')]
# [('elizabeth warren', 'PERSON')]
# [('trump administration axes', 'ORG'), ('nasa', 'ORG')]
# [("john mccain's", 'PERSON'), ('white house', 'ORG')]
# [('sarah palin', 'PERSON'), ('mccain', 'PERSON')]
# [('scott pruitt', 'PERSON'), ('day 1', 'DATE'), ('epa', 'ORG')]
# [('anti-muslim', 'NORP'), ('fbi', 'ORG'), ('texas', 'GPE')]
# [('cambridge analytica', 'ORG'), ('justice department', 'ORG'), ('fbi', 'ORG')]
# []
# [('washington', 'GPE'), ('this year', 'DATE')]
# [('joe biden berates', 'PERSON'), ('white house', 'ORG'), ("john mccain's", 'PERSON')]
# [('trump', 'PERSON'), ('kim jong un', 'PERSON'), ('next month', 'DATE'), ('singapore', 'GPE')]
# [('senate', 'ORG')]
# [('u.s.', 'GPE'), ('michigan', 'GPE')]
# [('the republican welfare plan', 'ORG')]
# [('trump', 'PERSON')]
# []
# [('democratic lawmaker', 'PERSON'), ('scott pruitt', 'PERSON'), ('senate', 'ORG')]
# [("mitch mcconnell's", 'PERSON'), ('gordon hartogensis', 'PERSON')]
# [('fbi', 'ORG'), ('cia', 'ORG')]
# [('chuck schumer', 'PERSON'), ('donald trump', 'PERSON')]
# []
# [('ted cruz', 'PERSON')]
# [('rex tillerson', 'ORG')]
# [('democrats', 'NORP')]
# [('russian', 'NORP')]
# [('giuliani', 'ORG'), ('cohen', 'PERSON')]
# [('trump', 'PERSON')]
# [('ferris bueller', 'PERSON'), ("donald trump's", 'PERSON')]
# [('katie porter', 'PERSON')]
# [('congressional candidate', 'ORG'), ('nra', 'ORG')]
# [('jared kushner', 'PERSON'), ('russians', 'NORP')]
# [('homeland security', 'ORG')]
# [('gina haspel', 'PERSON'), ('cia', 'ORG')]
# [('austin bars police department', 'ORG')]
# [('parkland dad', 'PERSON'), ('oliver north', 'PERSON'), ('nra', 'ORG')]
# [('blake', 'PERSON'), ('congress', 'ORG')]
# [('iowa', 'GPE')]
# [('melania trump', 'PERSON')]
# [('sarah huckabee', 'PERSON')]
# [('trump', 'ORG'), ('chinese', 'NORP'), ('u.s.', 'GPE'), ('iran', 'GPE')]
# [('jon tester', 'PERSON'), ('senate', 'ORG'), ('democrat', 'NORP')]
# []
# [('michael bloomberg', 'PERSON')]
# [('trump', 'PERSON')]
# [('michael avenatti', 'PERSON'), ('cohen', 'PERSON'), ('qatari', 'NORP')]
# [('donald trump', 'PERSON')]
# [('chinese', 'NORP'), ('china', 'GPE')]
# [('the nra convention', 'LAW')]
# [('americans', 'NORP'), ('iran', 'GPE')]
# [('lindsey graham', 'PERSON'), ('trump', 'GPE'), ('owe mccain', 'PERSON')]
# [('hundreds', 'CARDINAL'), ('u.s.', 'GPE')]
# [('tomi lahren', 'PERSON')]
# [('jews', 'NORP'), ('jerusalem', 'GPE')]
# [('u.s.', 'GPE'), ('jerusalem', 'GPE')]
# [('john bolton', 'PERSON'), ('european', 'NORP'), ('iran', 'GPE')]
# [('vermont', 'GPE')]
# [('missouri', 'GPE'), ('eric greitens', 'PERSON')]
# [('at least 16', 'CARDINAL')]
# [('blake farenthold', 'PERSON'), ('84,000', 'MONEY')]
# [('jared', 'ORG'), ('jerusalem', 'GPE')]
# [('michael cohen', 'PERSON'), ('600,000', 'MONEY'), ('at&t', 'ORG'), ('time warner', 'ORG')]
# [('white house', 'ORG')]
# []
# [('tomi lahren', 'PERSON')]
# [('georgia gop', 'PERSON')]
# [('california', 'GPE')]
# [('democrats', 'NORP')]
# [('debbie wasserman schultz', 'PERSON'), ('nra', 'ORG')]
# []
# [('harry reid', 'PERSON')]
# [('2', 'CARDINAL'), ("gina haspel's", 'PERSON'), ('cia', 'ORG')]
# []
# [('the white house', 'ORG')]
# [('south dakota congressional', 'ORG')]
# [('tomi lahren', 'PERSON')]
# [('michelle obama', 'PERSON')]
# [('supreme court', 'ORG')]
# [('george soros', 'PERSON'), ('millions', 'CARDINAL')]
# []
# [('aclu', 'ORG'), ('kris kobach', 'PERSON')]
# [('indiana', 'GPE'), ('slam joe', 'PERSON'), ('democrat', 'NORP')]
# [('senate', 'ORG'), ('democrat', 'NORP')]
# []
# [('republican', 'NORP')]
# [('9/11', 'CARDINAL'), ('cia', 'ORG'), ('gina', 'GPE')]
# [('trump accuser', 'PERSON'), ('democratic', 'NORP'), ('ohio', 'GPE')]
# []
# [('$32.8 million', 'MONEY')]
# [('gop', 'ORG'), ('tammy baldwin', 'PERSON'), ('cia', 'ORG')]
# [('indiana', 'GPE'), ('gop senate', 'ORG')]
# [('gop', 'ORG')]
# [('a year', 'DATE'), ('comey', 'PERSON')]
# []
# [('eric schneiderman', 'PERSON')]
# [('gina haspel', 'PERSON'), ('cia', 'ORG'), ('democrats', 'NORP')]
# [('gop', 'ORG'), ('ohio', 'GPE')]
# [('boulder city council', 'ORG')]
# [('mitch mcconnell', 'PERSON'), ('anti-lgbtq bigot', 'PERSON')]
# [('devin nunes', 'ORG'), ('fbi', 'ORG'), ('trump', 'PERSON')]
# [('mexican', 'NORP'), ('warns donald', 'PERSON')]
# [('russians', 'NORP')]
# [('trump', 'PERSON')]
# [('elizabeth warren’s', 'PERSON'), ('ohio', 'GPE'), ('democratic', 'NORP')]
# [('kushner', 'ORG')]
# [('eric schneiderman', 'PERSON')]
# [('fcc', 'ORG')]
# [('dean heller’s', 'PERSON'), ('more than $50,000', 'MONEY')]
# [('interior dept', 'ORG'), ('watchdog', 'ORG'), ('zinke', 'PERSON'), ('alaska', 'GPE')]
# [('bill gates', 'PERSON'), ('trump', 'PERSON')]
# [('robert wilkie', 'PERSON'), ('new va', 'GPE')]
# [('u.s.', 'GPE'), ('germany', 'GPE'), ('just hours', 'TIME'), ('first', 'ORDINAL')]
# [('trump', 'PERSON')]
# [('rudy giuliani', 'PERSON')]
# [('conservatives', 'NORP')]
# [('next year', 'DATE')]
# [('don jr.', 'PERSON')]
# []
# [('santa fe school', 'ORG')]
# ...
# [('israeli', 'NORP'), ('netanyahu', 'PERSON')]
# []
# [('anc', 'ORG'), ('south african', 'NORP'), ('jacob zuma', 'PERSON')]
# [('australia', 'GPE'), ('10 years', 'DATE')]
# [('iraq', 'GPE'), ('$88 billion', 'MONEY')]
# [('london airport', 'FAC'), ('world war', 'EVENT'), ('two', 'CARDINAL')]
# [('iranian', 'NORP'), ('65', 'CARDINAL')]
# [('winter olympics organizers', 'EVENT')]
# [('nbc apologizes', 'ORG'), ('commentator', 'ORG'), ('japan', 'GPE')]
# [('airliner crashes', 'PERSON'), ('russia', 'GPE'), ('71', 'CARDINAL')]
# [('pope francis renews', 'PERSON')]
# [('kim jong un', 'PERSON'), ('south korean', 'NORP'), ('moon', 'PERSON'), ('pyongyang', 'GPE')]
# [('israel', 'GPE'), ('syria', 'GPE')]
# [('hong kong', 'GPE'), ('at least 18', 'CARDINAL')]
# [("south korea's", 'GPE')]
# [('syrian', 'NORP')]
# [('australian', 'NORP')]
# [('south korea', 'GPE'), ('trump', 'GPE'), ('kim jong un', 'PERSON')]
# [('2 koreas', 'QUANTITY'), ('olympics', 'DATE')]
# [('australia', 'GPE')]
# [('pro-syrian', 'NORP'), ('more than 100', 'CARDINAL')]
# [('north korean', 'NORP')]
# []
# [('north korea', 'GPE'), ('2018', 'DATE'), ('winter', 'DATE')]
# [('american', 'NORP'), ('canada', 'GPE')]
# [('italy', 'GPE')]
# [('syrian kurdish', 'NORP'), ('2', 'CARDINAL')]
# [('iceland', 'GPE')]
# [('north korea', 'GPE'), ('winter', 'DATE'), ('olympics', 'EVENT')]
# [('kim jong un ‘', 'PERSON'), ('north korea', 'GPE')]
# [('north korea', 'GPE')]
# [('south korean', 'NORP'), ("north korea's", 'GPE'), ('kim jong un', 'PERSON')]
# [('65', 'CARDINAL'), ('iranian', 'NORP')]
# [('jokhang temple', 'PERSON'), ('tibetan', 'NORP')]
# [('5', 'CARDINAL'), ('russian', 'LANGUAGE')]
# [('uk', 'GPE'), ('islamophobic', 'NORP')]
# [('7.2-magnitude', 'CARDINAL'), ('mexico', 'GPE')]
# [('13', 'CARDINAL'), ('mexico', 'GPE')]
# [('angela merkel re', 'PERSON'), ('4th', 'ORDINAL')]
# [('north korea', 'GPE')]
# [('2', 'CARDINAL'), ('indian', 'NORP'), ('toronto', 'GPE')]
# [('thousands', 'CARDINAL'), ('ireland', 'GPE')]
# [('irish', 'NORP')]
# [('australia', 'GPE')]
# [('u.s.', 'GPE')]
# [('hundreds', 'CARDINAL'), ('russian', 'NORP')]
# [('uk', 'GPE'), ('russian', 'NORP')]
# [('australian', 'NORP'), ('3', 'CARDINAL')]
# [('brazil', 'GPE'), ("armed rio's", 'PERSON'), ('u.s.', 'GPE')]
# [('trump suggests', 'ORG'), ('north korea', 'GPE')]
# []
# [('south africa', 'GPE')]
# [('cyril ramaphosa', 'PERSON'), ("south africa's", 'GPE')]
# [('polish', 'NORP'), ('jews', 'NORP')]
# [('russia', 'GPE'), ('instagram', 'NORP'), ('kremlin', 'ORG')]
# [('france', 'GPE'), ('jewish', 'NORP'), ('nazis', 'NORP')]
# [("south africa's", 'GPE'), ('jacob zuma', 'PERSON')]
# [('north korea', 'GPE')]
# [('russian', 'NORP'), ('mh17', 'PRODUCT')]
# [('chloe kim', 'PERSON'), ('south korea', 'GPE')]
# [('cambodia', 'GPE')]
# [('yemen', 'GPE'), ('saudi arabia', 'GPE')]
# [('danish', 'NORP')]
# []
# [('kabul', 'GPE')]
# [('german', 'NORP')]
# [('australia', 'GPE')]
# [('u.s.', 'GPE'), ('syria', 'GPE')]
# [('daily', 'DATE'), ("'day", 'DATE')]
# [('myanmar', 'GPE')]
# [('u.s.', 'GPE'), ('european', 'NORP'), ('russia', 'GPE')]
# [('slovakia', 'ORG'), ('fico quits', 'PERSON')]
# [('australian', 'NORP')]
# []
# []
# [('moon', 'PERSON')]
# [('ireland', 'GPE')]
# [('putin', 'PERSON'), ('u.s.', 'GPE')]
# [('iranian', 'NORP'), ('u.s.', 'GPE')]
# [('thousands', 'CARDINAL')]
# [('fitness app strava', 'ORG')]
# [('100,000', 'CARDINAL'), ('un', 'ORG')]
# [('venezuela', 'GPE'), ('socialist', 'ORG'), ('nicolas maduro', 'PERSON')]
# [('iran', 'GPE'), ('europe', 'LOC'), ('america', 'GPE')]
# [('greek', 'NORP')]
# [('australia', 'GPE'), ('10', 'CARDINAL'), ('a decade', 'DATE')]
# [('trump', 'PERSON'), ('brexit', 'PERSON')]
# [('ikea', 'ORG'), ('ingvar kamprad', 'PERSON'), ('91', 'CARDINAL')]
# [('u.s.', 'GPE'), ('russia', 'GPE')]
# [('one year', 'DATE'), ('trump', 'GPE'), ('first', 'ORDINAL')]
# [('u.s.', 'GPE'), ('iraq', 'GPE')]
# [('putin', 'PERSON')]
# [('rio de janeiro', 'GPE')]
# [('australia', 'GPE')]
# [('rwandan', 'NORP'), ('first', 'ORDINAL')]
# [('australia', 'GPE')]
# [('kim jong un', 'PERSON'), ('winter olympics', 'EVENT'), ('north korean', 'NORP')]
# [('syrian', 'NORP'), ('russian', 'NORP')]
# [('hundreds', 'CARDINAL'), ('sudan', 'GPE')]
# [('america', 'GPE'), ('third', 'ORDINAL'), ('world cup', 'EVENT')]
# [('new zealand', 'GPE')]
# [('south korea', 'GPE')]
# [('poland', 'GPE')]
# [('un', 'ORG'), ('syria', 'GPE')]
# [('exposing ivory & rhino trade', 'ORG')]
# [('australian', 'NORP')]
# [('mercedes-benz', 'ORG'), ('china', 'GPE'), ('instagram', 'NORP')]
# [('france', 'GPE')]
# [('at least 5', 'CARDINAL'), ('6.4', 'CARDINAL'), ('taiwan', 'GPE')]
# [('winter olympics', 'EVENT'), ('south korea', 'GPE')]
# []
# [('canada', 'GPE')]
# [('shanghai', 'GPE')]
# [('fidel castro', 'PERSON'), ('fidel castro', 'PERSON'), ('68', 'CARDINAL')]
# [('wallaby', 'ORG'), ('sydney harbour', 'FAC')]
# [('90', 'CARDINAL'), ('libya', 'GPE')]
# [('australian', 'NORP')]
# [('iran', 'GPE')]
# [('mark zuckerberg', 'PERSON'), ('european', 'NORP')]
# [('iranian', 'NORP'), ('iran', 'GPE')]
# [('van', 'PERSON'), ('london', 'GPE'), ('43 years', 'DATE')]
# [('polish', 'NORP')]
# [('north korea', 'GPE'), ('south korea', 'GPE')]
# [('dozens', 'CARDINAL'), ('kabul', 'GPE')]
# [('north korea', 'GPE'), ('u.s.', 'GPE'), ("south korea's", 'GPE')]
# [("marielle franco's", 'ORG')]
# [('afghan', 'NORP'), ('ashraf ghani', 'PERSON'), ('taliban', 'ORG')]
# [("suu kyi's", 'PERSON'), ('myanmar', 'GPE')]
# [('toronto van attack', 'PERSON')]
# [('saudi', 'NORP'), ('at least 20', 'CARDINAL'), ('yemen', 'GPE')]
# [('armenian', 'NORP'), ('just a week', 'DATE')]
# [('3', 'CARDINAL'), ('mexican', 'NORP')]
# [('uk', 'GPE'), ('nazi', 'NORP')]
# [('thousands', 'CARDINAL'), ('nicaraguan', 'NORP')]
# [('u.s.', 'GPE'), ('syria', 'GPE')]
# [('danish', 'NORP'), ('kim wall', 'PERSON')]
# [('germans', 'NORP'), ('don kippas', 'PERSON'), ('solidarity', 'ORG'), ('jewish', 'NORP')]
# [('kim jong un', 'PERSON'), ('south korean', 'NORP'), ('moon', 'PERSON')]
# [('jewish', 'NORP'), ('slam putin', 'PERSON'), ('jews', 'NORP'), ('u.s.', 'GPE')]
# [('italians', 'NORP')]
# [("putin unveils new '", 'PERSON')]
# [('chinese', 'NORP'), ('george orwell', 'PERSON'), ('xi', 'PERSON')]
# [('canadian', 'NORP'), ('u.s.', 'GPE')]
# [('south korea', 'GPE'), ("kim jong un's", 'PERSON')]
# [('u.s.', 'GPE'), ('australians', 'NORP')]
# [('turkish', 'NORP'), ('7', 'CARDINAL'), ('iran', 'GPE')]
# [('myanmar', 'GPE')]
# [('korean', 'NORP'), ('korean', 'NORP')]
# []
# [('israeli', 'NORP'), ('3', 'CARDINAL'), ('gaza', 'GPE'), ('400', 'CARDINAL')]
# [('south korea', 'GPE')]
# [('palestinian', 'NORP'), ('israeli', 'NORP'), ('gaza', 'GPE')]
# [('israel', 'GPE'), ('dozens', 'CARDINAL'), ('syria', 'GPE')]
# [('norway', 'GPE'), ('2021', 'DATE'), ('lawmaker', 'PERSON')]
# [('israel', 'GPE'), ('syria', 'GPE'), ('iranian', 'NORP')]
# [('syrian', 'NORP'), ('russian', 'NORP')]
# [('paris', 'GPE'), ('20 years', 'DATE'), ('brussels', 'GPE')]
# [('north korea', 'GPE')]
# [('paris', 'GPE'), ('1', 'CARDINAL')]
# [("saudi arabia's", 'GPE')]
# [('prince charles', 'PERSON'), ('commonwealth', 'ORG'), ('queen', 'ORG')]
# [('german', 'NORP')]
# [('miguel diaz-canel', 'PERSON'), ('cuba', 'GPE'), ('60 years', 'DATE'), ('castro', 'PERSON')]
# [('germany', 'GPE')]
# [('south korea', 'GPE'), ('the korean war', 'EVENT'), ('korean', 'NORP')]
# []
# []
# [('north korean', 'NORP'), ('brazilian', 'NORP')]
# [('uk', 'GPE'), ('muslims', 'NORP')]
# [('north korea', 'GPE')]
# [('chinese', 'NORP')]
# [('democrats', 'NORP'), ('russia', 'GPE'), ('trump', 'LOC'), ('2016', 'DATE')]
# [('u.s.', 'GPE'), ('aung san suu kyi', 'PERSON')]
# [('french', 'NORP')]
# [('british', 'NORP'), ('trump', 'PERSON'), ('islamophobia', 'LOC')]
# [('india', 'GPE')]
# [('north korea', 'GPE'), ('u.s.', 'GPE')]
# [('at least 5', 'CARDINAL'), ('nicaragua', 'GPE'), ('social security', 'ORG')]
# [('the 19th century', 'DATE'), ('117', 'CARDINAL')]
# [('dublin', 'PERSON'), ('irish', 'NORP')]
# [('dozens', 'CARDINAL'), ('kabul', 'GPE')]
# [('nobel', 'WORK_OF_ART'), ('myanmar', 'GPE')]
# [('10', 'CARDINAL'), ('van rams', 'PERSON'), ('toronto', 'GPE')]
# [('pope francis buys gelato', 'PERSON'), ('rome', 'GPE')]
# [('mexican', 'NORP')]
# [('alfie evans', 'PERSON'), ('british', 'NORP'), ('center of legal battle', 'ORG')]
# [('david goodall', 'PERSON')]
# [('facebook', 'ORG')]
# [('italy', 'GPE'), ('european', 'NORP')]
# []
# []
# [('half', 'CARDINAL'), ('u.s.', 'GPE')]
# [('un', 'ORG'), ('iran', 'GPE')]
# [('north korea', 'GPE')]
# [('south korean', 'NORP'), ('kim jong un', 'PERSON'), ('pyongyang', 'GPE')]
# [('nikol pashinian', 'PERSON'), ('armenia', 'GPE')]
# [('kim jong un', 'PERSON'), ('xi jinping', 'PERSON')]
# [('netanyahu', 'PERSON'), ('iran', 'GPE')]
# [('netanyahu', 'PERSON'), ('japan', 'GPE'), ('dessert', 'PERSON')]
# [('iran', 'GPE')]
# [('first', 'ORDINAL'), ('syrian', 'NORP')]
# [('oskar', 'PERSON'), ('auschwitz', 'PERSON'), ('96', 'CARDINAL')]
# [('france', 'GPE')]
# [('russian', 'NORP'), ('putin', 'PERSON')]
# [('north korea', 'GPE'), ('u.s.', 'GPE')]
# [('north korea', 'GPE')]
# [('lebanese', 'NORP'), ('first', 'ORDINAL'), ('9 years', 'DATE')]
# [('pakistan', 'GPE'), ('23', 'CARDINAL')]
# []
# [('north korea', 'GPE'), ('u.s.', 'GPE')]
# [('indian', 'NORP')]
# [('martin', 'PERSON'), ('hurricanes irma', 'ORG'), ('maria', 'PERSON')]
# [('pakistani', 'NORP'), ('ahsan iqbal', 'PERSON'), ('gunman', 'ORG')]
# [('vladimir putin', 'PERSON'), ('another six years', 'DATE'), ('russia', 'GPE')]
# [('hezbollah', 'ORG')]
# [('vatican bank', 'ORG')]
# [('more than 200', 'CARDINAL'), ('may day', 'DATE'), ('paris', 'GPE')]
# [('north korea', 'GPE'), ('3', 'CARDINAL'), ('american', 'NORP')]
# []
# [('3', 'CARDINAL'), ('americans', 'NORP'), ('north korea', 'GPE'), ('the united states', 'GPE')]
# [('dozens', 'CARDINAL'), ('kenya', 'GPE')]
# [('thousands', 'CARDINAL'), ('spain', 'GPE'), ('5', 'CARDINAL')]
# [('british', 'NORP'), ('interior', 'ORG'), ('amber rudd', 'PERSON')]
# [('seoul', 'GPE'), ('north korea', 'GPE')]
# [('syrians', 'NORP')]
# [('benjamin netanyahu', 'PERSON'), ('iran', 'GPE')]
# [('afghanistan', 'GPE')]
# [('thousands', 'CARDINAL'), ('moscow', 'GPE')]
# [('afghanistan', 'GPE')]
# [('afghanistan', 'GPE'), ('dozens', 'CARDINAL'), ('11', 'CARDINAL')]
# [('muslims', 'NORP'), ('at least 950', 'CARDINAL'), ('germany', 'GPE'), ('2017', 'DATE')]
# [('russia', 'GPE'), ('uk', 'GPE')]
# [('italian', 'NORP')]
# [('u.s.', 'GPE')]
# [("benjamin netanyahu's", 'PERSON'), ('iran', 'GPE')]
# [('asian-american', 'NORP'), ('china', 'GPE')]
# [('sao paulo', 'GPE'), ('at least 1', 'CARDINAL')]
# [('cardinal george pell', 'PERSON'), ('vatican treasurer', 'PERSON')]
# [('france', 'GPE')]
# [('french', 'NORP'), ('hubert de givenchy', 'PERSON'), ('91', 'CARDINAL')]
# [('russian', 'NORP'), ('uk', 'GPE')]
# [('papua new guinea', 'GPE')]
# [('italy', 'GPE')]
# [('america', 'GPE'), ('australia', 'GPE')]
# [('italian', 'NORP'), ('31', 'CARDINAL')]
# [('iranian', 'NORP'), ('u.s.', 'GPE'), ('u.s.', 'GPE')]
# [('europeans', 'NORP'), ('iran', 'GPE')]
# [('2 months later', 'DATE'), ('rio cops', 'PERSON'), ('marielle', 'GPE')]
# [('south korean', 'NORP'), ('north korean', 'NORP'), ('92', 'CARDINAL')]
# [('der spiegel', 'PERSON'), ('europe', 'LOC')]
# [('safari park', 'FAC')]
# [('russia', 'GPE'), ('u.s.', 'GPE')]
# [('malala yousafzai', 'GPE'), ('pakistan', 'GPE'), ('6 years', 'DATE')]
# [('amnesty international slams', 'ORG'), ('trump', 'GPE')]
# [('north korea', 'GPE')]
# [('israeli', 'NORP'), ('at least 16', 'CARDINAL'), ('palestinian', 'NORP'), ('gaza', 'GPE')]
# [('6.9', 'CARDINAL'), ('papua new guinea', 'GPE')]
# [('israeli', 'NORP'), ('13', 'CARDINAL'), ('gaza border', 'GPE')]
# [('u.s.', 'GPE'), ('syria', 'GPE')]
# [("pippa middleton's", 'PERSON')]
# [('kim jong un', 'PERSON'), ('south korean', 'NORP'), ('pyongyang', 'GPE')]
# [('u.s.', 'GPE'), ('israel', 'GPE'), ('jerusalem', 'GPE')]
# [('u.s.', 'GPE'), ('australia', 'GPE')]
# [('china', 'GPE'), ('128', 'CARDINAL'), ('u.s.', 'GPE')]
# [('winnie madikizela-mandela', 'PERSON'), ('81', 'CARDINAL')]
# []
# [('australia', 'GPE')]
# [('u.n. security council', 'ORG'), ('syria', 'GPE')]
# [('british muslims', 'NORP'), ('muslim', 'NORP')]
# [('israel', 'GPE'), ('hours', 'TIME'), ('u.n.', 'GPE')]
# [("north korea's", 'GPE')]
# [('malaysia', 'GPE'), ('up to six years', 'DATE')]
# []
# [('china', 'GPE'), ('u.s.', 'GPE'), ('$50 billion', 'MONEY')]
# [('one', 'CARDINAL'), ('dea', 'ORG')]
# [('syria', 'GPE')]
# [('saudi arabia', 'GPE')]
# [('india', 'GPE'), ('one', 'CARDINAL')]
# [('venezuelan police', 'ORG'), ('68', 'CARDINAL')]
# [("kim jong un's", 'PERSON'), ('china', 'GPE')]
# [('sichuan airlines co-pilot', 'ORG')]
# [('china', 'GPE'), ('u.s.', 'GPE'), ('pandora', 'PERSON')]
# [('france', 'GPE')]
# [('thousands', 'CARDINAL'), ('poland', 'GPE')]
# [('french', 'NORP')]
# [('dozens', 'CARDINAL'), ('russian', 'NORP')]
# [('1', 'CARDINAL'), ('houthi', 'ORG'), ('saudi arabian', 'NORP')]
# [('catalan', 'NORP'), ('carles puigdemont', 'PERSON'), ('germany', 'GPE')]
# []
# []
# [('syria', 'GPE')]
# [('syria', 'GPE'), ('un', 'ORG')]
# [('russia', 'GPE')]
# [('russia', 'GPE')]
# [('kim jong un', 'PERSON'), ('china', 'GPE')]
# [('north korean', 'NORP'), ('olympics', 'EVENT')]
# [('un', 'ORG'), ('syria', 'GPE')]
# [('u.s.', 'GPE'), ('montenegro', 'GPE')]
# [('russian', 'NORP')]
# [('kim jong un', 'PERSON'), ('xi jinping', 'PERSON'), ('china', 'GPE')]
# [('french', 'NORP'), ('jewish', 'NORP'), ('holocaust', 'DATE')]
# [('trump backs', 'PERSON'), ('u.k.', 'GPE'), ('russia', 'GPE')]
# [('ecuador', 'GPE'), ('wikileaks', 'NORP')]
# [('amal clooney', 'PERSON'), ('reuters', 'ORG'), ('myanmar', 'GPE')]
# [('muslims', 'NORP'), ('sri lanka', 'GPE')]
# [('thousands', 'CARDINAL'), ('france', 'GPE')]
# [('south korea', 'GPE'), ('april date', 'DATE')]
# [('russian', 'NORP'), ('uk', 'GPE')]
# [('muqtada al-sadr', 'PERSON'), ('iraq', 'GPE')]
# [('palestinian', 'NORP'), ('israeli', 'NORP'), ('gaza protest crackdown', 'GPE')]
# [('israeli', 'NORP'), ('pm benjamin netanyahu', 'PERSON')]
# []
# []
# [('brazilian', 'NORP'), ('lula defies', 'PERSON')]
# [('muslim australian', 'NORP'), ('u.s.', 'GPE')]
# [('israelis', 'NORP')]
# [('soviet nerve', 'ORG'), ('ex-russian', 'NORP')]
# [('6', 'CARDINAL')]
# [('syrian', 'NORP')]
# [('at least 11', 'CARDINAL'), ('dozens', 'CARDINAL'), ('indonesia', 'GPE')]
# [('iran', 'GPE'), ('u.s.', 'GPE')]
# []
# [('indian', 'NORP')]
# [('christian', 'NORP'), ('jerusalem', 'GPE'), ('israeli', 'NORP')]
# []
# [('tens of thousands', 'CARDINAL'), ('hungary', 'GPE'), ('viktor orbán', 'PERSON')]
# [('syrian', 'NORP'), ('malaysian', 'NORP'), ('weeks', 'DATE')]
# [('syrian air defense', 'ORG')]
# [('u.s.', 'GPE'), ('russia', 'GPE'), ('syria', 'GPE')]
# [('syrian', 'NORP'), ('9', 'CARDINAL')]
# [('rome', 'GPE'), ('winter', 'DATE')]
# [('china', 'GPE'), ('xi jinping', 'PERSON')]
# [('russian', 'NORP'), ('maxim borodin', 'PERSON')]
# [('russia', 'GPE')]
# [('syrian', 'NORP')]
# [('australia', 'GPE')]
# [('at least 50', 'CARDINAL'), ('kathmandu airport', 'FAC')]
# [('chinese', 'NORP')]
# [('the quebec mosque shooting', 'ORG')]
# []
# [('raul castro', 'PERSON'), ('cuba', 'GPE')]
# [('4', 'CARDINAL')]
# [('over 100', 'CARDINAL'), ('nigerian', 'NORP'), ('new boko haram', 'PERSON')]
# [('syria', 'GPE')]
# [('myanmar', 'GPE'), ('2', 'CARDINAL'), ('reuters', 'ORG')]
# [('u.s.', 'GPE'), ('jerusalem', 'GPE')]
# [('israeli', 'NORP'), ('dozens', 'CARDINAL'), ('palestinians', 'NORP'), ('u.s.', 'GPE'), ('jerusalem', 'GPE')]
# []
# [('south korean', 'NORP'), ('park geun-hye', 'PERSON'), ('24 years', 'DATE')]
# [('myanmar', 'GPE')]
# [('salman khan', 'PERSON'), ('bollywood', 'GPE'), ('5 years', 'DATE')]
# [('2', 'CARDINAL'), ('20', 'CARDINAL'), ('german', 'NORP')]
# [('two', 'CARDINAL'), ('u.s.', 'GPE'), ('kentucky', 'GPE')]
# [('hungary', 'GPE')]
# [('palestinian', 'NORP'), ('israel', 'GPE')]
# [('papua new guinea', 'GPE')]
# [('hungary', 'GPE')]
# [('german', 'NORP'), ('berlin', 'GPE'), ('half', 'CARDINAL')]
# [('austria', 'GPE')]
# [('dozens', 'CARDINAL'), ('syrian', 'NORP')]
# [('bollywood superstar sridevi', 'ORG'), ('54', 'CARDINAL')]
# [('rome', 'GPE'), ('pakistan', 'GPE')]
# [('india', 'GPE'), ('at least 27', 'CARDINAL')]
# [('2013', 'CARDINAL'), ('syrian', 'NORP')]
# [('israel', 'GPE'), ('syria', 'GPE')]
# [('pope francis', 'PERSON')]
# [('trump', 'PERSON'), ('kim jong un', 'PERSON'), ('early june', 'DATE')]
# [('gaza', 'GPE'), ('israel', 'GPE')]
# [('japanese', 'NORP')]
# [('russian', 'NORP')]
# [('mary', 'PERSON'), ('kate', 'PERSON'), ('william', 'PERSON'), ('3', 'CARDINAL')]
# [('syrian', 'NORP')]
# [('algerian', 'NORP'), ('over 250', 'CARDINAL')]
# [('china', 'GPE')]
# []

# %%
#df.to_csv('news_classification_model_final.csv', encoding='utf-8', index=False)

# %%
#shutil.copy('news_classification_model_final.csv','/content/drive/MyDrive/Colab Notebooks/news_final.csv')
# Out:
# '/content/drive/MyDrive/Colab Notebooks/news_final.csv'

# %%
#new column
df["lable"] = ""

# %%
import spacy
import os
## call model
ner = spacy.load('en_core_web_lg')
## tag text
txt = df["text"].iloc[0]
doc = ner(txt)
## display result
spacy.displacy.render(doc, style="ent")

# %%
## tag text and exctract tags into a list
df["lable"] = df["words"].apply(lambda x: [(tag.text, tag.label_)
                                for tag in ner(x).ents] )

# %%
## tag text and exctract tags into a list
dtf["tags"] = dtf["text"].apply(lambda x: [(tag.text, tag.label_)
                                for tag in ner(x).ents] )

# %% [markdown]
# **process words**

# %%
import spacy
from spacy import displacy
from  spacy.lang.en.stop_words import STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer
import en_core_web_sm
import string
import nltk

# %%
nlp = spacy.load('en_core_web_sm')

# %%
stopwords = list(STOP_WORDS)
print(stopwords[:])
punctuations = string.punctuation
print(punctuations)
# Out:
# ['can', 'however', 'him', 'therein', 'elsewhere', 'perhaps', 'latterly', 'eight', 'you', 'beforehand', 'more', 'both', 'first', 'had', 'on', 'twelve', 'themselves', 'may', 'otherwise', 'has', 'whither', 'will', 'becoming', 'per', 'wherein', 'many', 'ourselves', 'made', 'please', 'although', 'four', 'some', "'s", 'himself', 'where', 'whereupon', 'becomes', 'this', 'out', 'indeed', 'thus', 'our', 'else', 'around', 'anywhere', 'my', 'thereby', 'nothing', 'from', 'amount', 'we', 'about', 'too', 'when', '‘d', 'after', 'could', 'its', 'behind', 'to', 'formerly', 'serious', 'eleven', 'through', 'is', 'most', 'somehow', 'fifty', 'thence', 'give', "n't", 'that', 'make', 'myself', 'seem', 'i', 'but', 'several', 'also', 'moreover', 'rather', 'another', 'enough', 'always', 'it', 'what', 'full', 'thru', 'together', 'well', 'be', 'would', 'upon', 'move', 'therefore', 'why', 'other', 'whom', 'throughout', 'others', 'not', 'everywhere', 'does', 'wherever', '’ll', 'hundred', 'those', 'own', 'whereas', 'into', 'below', 'above', 'somewhere', 'bottom', 'something', 'each', 'never', '‘s', 'without', 'regarding', 'until', 'being', 'often', 'yours', 'by', 'thereupon', 'latter', 'do', 'onto', 'become', 'nevertheless', 'no', 'all', 'of', 'your', 'put', 'go', 'meanwhile', 'were', 'sixty', 'someone', 'really', '’d', 'anyway', 'empty', 'namely', 'former', 'ever', 'name', 'get', "'d", 'and', 'how', "'ve", 'hereafter', 'show', 'ours', '’ve', 'least', 'mine', '‘ll', '‘re', 'part', 'besides', 'than', 'been', 'fifteen', 'these', 'anything', '‘ve', 'along', 'whoever', 'next', 'either', 'mostly', 'seemed', 'me', 'even', 'over', 'while', 'two', 'under', 'cannot', 'using', 'or', 'hence', 'during', 'further', 'sometimes', 'see', 'once', 'her', 'the', 'unless', 'only', 'again', 'am', 'same', 'as', 'there', 'say', 'just', 'everything', 'keep', 'hers', 'various', 'call', 'a', 'few', 'everyone', 'seeming', 'now', 'hereby', 'itself', 'last', '’m', 'did', 'twenty', 'forty', 'up', 'are', 'used', 'anyhow', 'alone', 'noone', 'yourself', 'any', 'sometime', 'between', 'toward', "'re", 'beyond', 'nor', 'thereafter', 'should', 'he', 'none', 'towards', 'us', 'five', 'neither', 'nowhere', 'done', 'since', 'still', 'nine', 'then', 'against', '‘m', 'back', 'with', 'their', '’s', 'less', 'an', 'whose', '’re', 'who', 'yourselves', 'hereupon', 'beside', 'already', "'ll", 'because', "'m", 'whereafter', 'at', 'six', 'front', 'via', 'whatever', 'whenever', 'anyone', 'which', 'across', 'for', 'one', 'herself', 'nobody', 'they', 'much', 'three', 'so', 'except', 'due', 'herein', 'must', 'might', 'yet', 'within', 'was', 'n’t', 'them', 'every', 'his', 'seems', 'among', 'very', 'off', 'though', 'ca', 'afterwards', 'before', 'top', 'doing', 'in', 'n‘t', 'third', 'such', 'take', 'side', 'down', 'whether', 'ten', 'almost', 'whole', 'she', 'here', 'amongst', 'quite', 're', 'became', 'whereby', 'have', 'if', 'whence']
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# Function to tokenise the text
def tokeniser(sentence):

    # Process the text
    doc = nlp(sentence)

    # Rule 1
    # Convert tokens to lemma form for all except '-PRON-'
    # Remember (from SpaCy introduction) : Tokens like I, my, me were represented as '-PRON-' by lemma attribute
    tokens = [ token.lemma_.lower().strip() if token.lemma_ != "-PRON-" else token.lower_ for token in doc ]

    # Rule 2
    # Remove stop words and punctuation
    tokens = [ token for token in tokens if token not in stopwords and token not in punctuations ]

    return tokens

# %%
tfvectorizer = TfidfVectorizer(tokenizer = tokeniser)

# %%
df.shape
df.isna().sum()
# Out:
# category    0
# text        0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( df['category'], df['text'],
                                                    test_size = 0.2, random_state = 100)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB

# %%
classifier_NB = MultinomialNB()

# %%
from sklearn.pipeline import Pipeline

# %%
model_pipe_NB = Pipeline( [ ('vectorizer', tfvectorizer),
                         ('classifier', classifier_NB) ] )

# %%
model_pipe_NB.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('vectorizer',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 1), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokeniser at 0x7fead908b8c0>,
#                                  use_idf=True, vocabulary=None)),
#                 ('classifier',
#                  MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
preds = model_pipe_NB.predict(X_test)

# %%
# Accuracy
print("Train Accuracy: ", model_pipe_NB.score(X_train, y_train))

# Accuracy
print("Test Accuracy: ", model_pipe_NB.score(X_test, y_test))
# Out:
# Train Accuracy:  0.0035
# Test Accuracy:  0.0

# %%
import pickle

# %%
filename = 'NB_model_5cat_data.sav'
pickle.dump(model_pipe_NB, open(filename, 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))

# %% [markdown]
# Predict on test data

# %%
preds = model_pipe_NB.predict(X_test)

# %%
preds[:10]
# Out:
# array(['"How Do Asian Americans Advocate for Equality Without Throwing Other People of Color Under the Bus?"',
#        '"Age Shall Not Weary Them" - Shakespeare and Memorial Day',
#        '"How Do Asian Americans Advocate for Equality Without Throwing Other People of Color Under the Bus?"',
#        'The Rest Of The World Showed Up To March For Our Lives',
#        '#MeToo In The Statehouse: At Least 16 Men Are Gone, But The Harassment Culture Isn’t',
#        '"How Do Asian Americans Advocate for Equality Without Throwing Other People of Color Under the Bus?"',
#        '#MeToo In The Statehouse: At Least 16 Men Are Gone, But The Harassment Culture Isn’t',
#        '"How Do Asian Americans Advocate for Equality Without Throwing Other People of Color Under the Bus?"',
#        '"Age Shall Not Weary Them" - Shakespeare and Memorial Day',
#        '"How Do Asian Americans Advocate for Equality Without Throwing Other People of Color Under the Bus?"'],
#       dtype='<U181')

# %%
X_test[:10]
# Out:
# 55159     EDUCATION
# 92847          ARTS
# 19231     EDUCATION
# 7510     WORLD NEWS
# 434        POLITICS
# 36616     EDUCATION
# 913        POLITICS
# 26219     EDUCATION
# 92954          ARTS
# 19157     EDUCATION
# Name: category, dtype: object

# %%
y_test[:10]
# Out:
# 55159    How to Answer the Common Application Essay for...
# 92847    Inside The Strange And Beautiful Bromance Of D...
# 19231    Circle Up: Teaching Social-Emotional Skills Ye...
# 7510     Myanmar And Bangladesh Establish 2-Year Timefr...
# 434      Federal Prosecutors Still Trying To Turn Trump...
# 36616    Donald Trump Says Our Schools Are 'Flush With ...
# 913      Mitch McConnell Mocks Blankenship On Twitter W...
# 26219                                   No Excuse Teaching
# 92954    Relating to Race Over Dinner: "Memphis" in For...
# 19157    Inspired By Skid Row, Educator Opening Charter...
# Name: text, dtype: object

# %% [markdown]
# Compute accuracy

# %%
# Accuracy
print("Train Accuracy: ", model_pipe_NB.score(X_train, y_train))

# Accuracy
print("Test Accuracy: ", model_pipe_NB.score(X_test, y_test))
# Out:
# Train Accuracy:  0.0035
# Test Accuracy:  0.0

# %% [markdown]
# https://www.kaggle.com/jeffd23/10-classifier-showdown-in-scikit-learn
